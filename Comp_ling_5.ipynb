# %% [markdown]
# # Домашнее задание  № 5. Матричные разложения/Тематическое моделирование

# %% [markdown]
# ### Задание № 1 (4 балла)

# %% [markdown]
# Попробуйте матричные разложения с 5 классификаторами - SGDClassifier, KNeighborsClassifier,  RandomForest, ExtraTreesClassifier (про него подробнее почитайте в документации, он похож на RF). Используйте и NMF и SVD. Сравните результаты на кросс-валидации и выберите лучшее сочетание.
#
# В итоге у вас должно получиться, как минимум 10 моделей (два разложения на каждый классификатор). Используйте 1 и те же параметры кросс-валидации. Параметры векторизации, параметры K в матричных разложениях, параметры классификаторов могут быть разными между экспериментами.

# %% [markdown]
# Можете взять поменьше данных, если все будет обучаться слишком долго (не ставьте параметр K слишком большим в NMF, иначе точно будет слишком долго)

# %%
import gensim
import pandas as pd
import numpy as np
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim_models
from collections import Counter
from string import punctuation
from razdel import tokenize as razdel_tokenize
from sklearn.decomposition import TruncatedSVD, NMF, PCA, LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_distances
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, StratifiedKFold

# %%
morph = MorphAnalyzer()

# %%
data = pd.read_csv('avito_category_classification.csv')

# %%
def normalize(text):
    normalized_text = [word.text.strip(punctuation) for word in razdel_tokenize(text)]
    normalized_text = [word.lower() for word in normalized_text if word and len(word) < 20 ]
    normalized_text = [morph.parse(word)[0].normal_form for word in normalized_text]
    return ' '.join(normalized_text)

# %%
data['description_norm'] = data['description'].apply(normalize)

# %%
def eval_table(X, y, pipeline, N=6):
    # зафиксируем порядок классов
    labels = list(set(y))
    
    # метрики отдельных фолдов будет хранить в табличке
    fold_metrics = pd.DataFrame(index=labels)
    # дополнительно также соберем таблицу ошибок
    errors = np.zeros((len(labels), len(labels)))
    
    # создаем стратегию кросс-валидации
    # shuffle=True (перемешивание) - часто критично важно указать
    # т.к. данные могут быть упорядочены и модель на этом обучится
    kfold = StratifiedKFold(n_splits=N, shuffle=True, )
    
    for i, (train_index, test_index) in enumerate(kfold.split(X, y)):
        # fit-predict как и раньше, но сразу пайплайном
        pipeline.fit(X[train_index], y[train_index])
        preds = pipeline.predict(X[test_index])
        
        # записываем метрику и индекс фолда
        fold_metrics[f'precision_{i}'] = precision_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'recall_{i}'] = recall_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'f1_{i}'] = f1_score(y[test_index], preds, labels=labels, average=None)
        errors += confusion_matrix(y[test_index], preds, labels=labels, normalize='true')
    
    # таблица для усредненных значений
    # тут мы берем колонки со значениями и усредняем их
    # часто также все метрики сразу суммируют и в конце просто делят на количество фолдов
    # но мы тут помимо среднего также хотим посмотреть на стандартное отклонение
    # чтобы понять как сильно варьируются оценки моделей
    result = pd.DataFrame(index=labels)
    result['precision'] = fold_metrics[[f'precision_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['precision_std'] = fold_metrics[[f'precision_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['recall'] = fold_metrics[[f'recall_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['recall_std'] = fold_metrics[[f'recall_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['f1'] = fold_metrics[[f'f1_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['f1_std'] = fold_metrics[[f'f1_{i}' for i in range(N)]].std(axis=1).round(2)
    
    # добавим одну колонку со средним по всем классам
    result.loc['mean'] = result.mean().round(2)
    # проценты ошибок просто усредняем
    errors /= N
    
    return result, errors

# %% [markdown]
# **SGDClassifier**

# %%
pipeline_nmf_sgd = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('nmf', NMF(200)),
    ('clf', SGDClassifier(max_iter=200))
])

pipeline_svd_sgd = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(200)),
    ('clf', SGDClassifier(max_iter=200))
])

# %%
metrics_nmf_sgd, errors_bow_sgd = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_sgd)
metrics_svd_sgd, errors_svd_sgd = eval_table(data['description_norm'], data['category_name'], pipeline_svd_sgd)

# %%
metrics_nmf_sgd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.52           0.09    0.63        0.10
# Мебель и интерьер                0.73           0.14    0.14        0.08
# Бытовая техника                  0.54           0.21    0.12        0.08
# Предложение услуг                0.58           0.19    0.55        0.19
# Детская одежда и обувь           0.63           0.09    0.62        0.09
# Телефоны                         0.70           0.10    0.49        0.09
# Ремонт и строительство           0.56           0.13    0.19        0.08
# Квартиры                         0.76           0.20    0.91        0.07
# Товары для детей и игрушки       0.60           0.11    0.39        0.09
# Автомобили                       0.73           0.28    0.71        0.16
# mean                             0.64           0.15    0.48        0.10
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.56    0.03
# Мебель и интерьер           0.22    0.11
# Бытовая техника             0.19    0.10
# Предложение услуг           0.50    0.08
# Детская одежда и обувь      0.62    0.02
# Телефоны                    0.57    0.03
# Ремонт и строительство      0.27    0.08
# Квартиры                    0.81    0.14
# Товары для детей и игрушки  0.46    0.04
# Автомобили                  0.66    0.20
# mean                        0.49    0.08

# %%
metrics_svd_sgd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.65           0.03    0.79        0.04
# Мебель и интерьер                0.64           0.07    0.56        0.06
# Бытовая техника                  0.63           0.09    0.42        0.09
# Предложение услуг                0.72           0.06    0.71        0.07
# Детская одежда и обувь           0.77           0.05    0.69        0.03
# Телефоны                         0.81           0.09    0.78        0.03
# Ремонт и строительство           0.55           0.09    0.44        0.08
# Квартиры                         0.95           0.03    0.95        0.02
# Товары для детей и игрушки       0.68           0.11    0.63        0.08
# Автомобили                       0.85           0.05    0.89        0.05
# mean                             0.72           0.07    0.69        0.06
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.71    0.02
# Мебель и интерьер           0.59    0.03
# Бытовая техника             0.50    0.08
# Предложение услуг           0.71    0.02
# Детская одежда и обувь      0.73    0.02
# Телефоны                    0.79    0.04
# Ремонт и строительство      0.48    0.04
# Квартиры                    0.95    0.01
# Товары для детей и игрушки  0.65    0.04
# Автомобили                  0.87    0.02
# mean                        0.70    0.03

# %%
metrics_nmf_sgd - metrics_svd_sgd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.13           0.06   -0.16        0.06
# Мебель и интерьер                0.09           0.07   -0.42        0.02
# Бытовая техника                 -0.09           0.12   -0.30       -0.01
# Предложение услуг               -0.14           0.13   -0.16        0.12
# Детская одежда и обувь          -0.14           0.04   -0.07        0.06
# Телефоны                        -0.11           0.01   -0.29        0.06
# Ремонт и строительство           0.01           0.04   -0.25        0.00
# Квартиры                        -0.19           0.17   -0.04        0.05
# Товары для детей и игрушки      -0.08           0.00   -0.24        0.01
# Автомобили                      -0.12           0.23   -0.18        0.11
# mean                            -0.08           0.08   -0.21        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары  -0.15    0.01
# Мебель и интерьер          -0.37    0.08
# Бытовая техника            -0.31    0.02
# Предложение услуг          -0.21    0.06
# Детская одежда и обувь     -0.11    0.00
# Телефоны                   -0.22   -0.01
# Ремонт и строительство     -0.21    0.04
# Квартиры                   -0.14    0.13
# Товары для детей и игрушки -0.19    0.00
# Автомобили                 -0.21    0.18
# mean                       -0.21    0.05

# %% [markdown]
# По всем метрикам SVD гораздо лучше.

# %% [markdown]
# **KNeighborsClassifier**

# %%
pipeline_nmf_knc = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), max_features = 2000)),
    ('nmf', NMF(300)),
    ('clf', KNeighborsClassifier())
])

pipeline_svd_knc = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), max_features = 2000)),
    ('svd', TruncatedSVD(300)),
    ('clf', KNeighborsClassifier())
])

# %%
metrics_nmf_knc, errors_bow_knc = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_knc)
metrics_svd_knc, errors_svd_knc = eval_table(data['description_norm'], data['category_name'], pipeline_svd_knc)

# %%
metrics_nmf_knc
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.48           0.03    0.59        0.02
# Мебель и интерьер                0.31           0.07    0.25        0.05
# Бытовая техника                  0.19           0.03    0.20        0.02
# Предложение услуг                0.47           0.04    0.46        0.08
# Детская одежда и обувь           0.50           0.03    0.58        0.05
# Телефоны                         0.59           0.05    0.37        0.09
# Ремонт и строительство           0.29           0.10    0.17        0.06
# Квартиры                         0.80           0.06    0.62        0.06
# Товары для детей и игрушки       0.41           0.05    0.24        0.05
# Автомобили                       0.45           0.02    0.58        0.08
# mean                             0.45           0.05    0.41        0.06
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.53    0.01
# Мебель и интерьер           0.27    0.06
# Бытовая техника             0.19    0.02
# Предложение услуг           0.46    0.06
# Детская одежда и обувь      0.53    0.04
# Телефоны                    0.45    0.07
# Ремонт и строительство      0.21    0.07
# Квартиры                    0.69    0.05
# Товары для детей и игрушки  0.30    0.05
# Автомобили                  0.51    0.04
# mean                        0.41    0.05

# %%
metrics_svd_knc
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.47           0.02    0.59        0.02
# Мебель и интерьер                0.34           0.08    0.25        0.02
# Бытовая техника                  0.28           0.05    0.32        0.04
# Предложение услуг                0.57           0.03    0.57        0.07
# Детская одежда и обувь           0.49           0.02    0.60        0.04
# Телефоны                         0.68           0.11    0.33        0.04
# Ремонт и строительство           0.28           0.05    0.15        0.03
# Квартиры                         0.93           0.02    0.75        0.04
# Товары для детей и игрушки       0.49           0.07    0.24        0.02
# Автомобили                       0.58           0.08    0.61        0.05
# mean                             0.51           0.05    0.44        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.52    0.02
# Мебель и интерьер           0.28    0.03
# Бытовая техника             0.30    0.04
# Предложение услуг           0.57    0.04
# Детская одежда и обувь      0.54    0.03
# Телефоны                    0.44    0.05
# Ремонт и строительство      0.20    0.03
# Квартиры                    0.83    0.02
# Товары для детей и игрушки  0.32    0.03
# Автомобили                  0.60    0.06
# mean                        0.46    0.04

# %%
metrics_nmf_knc - metrics_svd_knc
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.01           0.01    0.00        0.00
# Мебель и интерьер               -0.03          -0.01    0.00        0.03
# Бытовая техника                 -0.09          -0.02   -0.12       -0.02
# Предложение услуг               -0.10           0.01   -0.11        0.01
# Детская одежда и обувь           0.01           0.01   -0.02        0.01
# Телефоны                        -0.09          -0.06    0.04        0.05
# Ремонт и строительство           0.01           0.05    0.02        0.03
# Квартиры                        -0.13           0.04   -0.13        0.02
# Товары для детей и игрушки      -0.08          -0.02    0.00        0.03
# Автомобили                      -0.13          -0.06   -0.03        0.03
# mean                            -0.06           0.00   -0.03        0.02
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.01   -0.01
# Мебель и интерьер          -0.01    0.03
# Бытовая техника            -0.11   -0.02
# Предложение услуг          -0.11    0.02
# Детская одежда и обувь     -0.01    0.01
# Телефоны                    0.01    0.02
# Ремонт и строительство      0.01    0.04
# Квартиры                   -0.14    0.03
# Товары для детей и игрушки -0.02    0.02
# Автомобили                 -0.09   -0.02
# mean                       -0.05    0.01

# %% [markdown]
# По F-мере незначительно лучше SVD.

# %% [markdown]
# **RandomForestClassifier**

# %%
pipeline_nmf_rf = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('nmf', NMF(200)),
    ('clf', RandomForestClassifier(n_estimators=50, max_depth=10))
])

pipeline_svd_rf = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(200)),
    ('clf', RandomForestClassifier(n_estimators=50, max_depth=10))
])

# %%
metrics_nmf_rf, errors_bow_rf = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_rf)
metrics_svd_rf, errors_svd_rf = eval_table(data['description_norm'], data['category_name'], pipeline_svd_rf)

# %%
metrics_nmf_rf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.45           0.02    0.82        0.01
# Мебель и интерьер                0.76           0.07    0.31        0.08
# Бытовая техника                  0.00           0.00    0.00        0.00
# Предложение услуг                0.73           0.06    0.51        0.04
# Детская одежда и обувь           0.67           0.02    0.68        0.02
# Телефоны                         0.81           0.08    0.61        0.08
# Ремонт и строительство           0.78           0.20    0.05        0.03
# Квартиры                         0.90           0.02    0.94        0.02
# Товары для детей и игрушки       0.86           0.06    0.37        0.04
# Автомобили                       0.90           0.04    0.75        0.07
# mean                             0.69           0.06    0.50        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.58    0.02
# Мебель и интерьер           0.44    0.08
# Бытовая техника             0.00    0.00
# Предложение услуг           0.60    0.05
# Детская одежда и обувь      0.67    0.02
# Телефоны                    0.69    0.06
# Ремонт и строительство      0.10    0.05
# Квартиры                    0.92    0.02
# Товары для детей и игрушки  0.52    0.05
# Автомобили                  0.81    0.04
# mean                        0.53    0.04

# %%
metrics_svd_rf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.47           0.01    0.73        0.02
# Мебель и интерьер                0.78           0.23    0.06        0.02
# Бытовая техника                  0.84           0.20    0.08        0.06
# Предложение услуг                0.68           0.07    0.59        0.05
# Детская одежда и обувь           0.47           0.01    0.67        0.02
# Телефоны                         0.89           0.06    0.41        0.02
# Ремонт и строительство           0.63           0.09    0.12        0.02
# Квартиры                         0.91           0.04    0.89        0.04
# Товары для детей и игрушки       0.73           0.07    0.24        0.05
# Автомобили                       0.80           0.02    0.67        0.05
# mean                             0.72           0.08    0.45        0.03
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.57    0.01
# Мебель и интерьер           0.10    0.03
# Бытовая техника             0.14    0.10
# Предложение услуг           0.63    0.04
# Детская одежда и обувь      0.55    0.01
# Телефоны                    0.56    0.03
# Ремонт и строительство      0.20    0.04
# Квартиры                    0.90    0.02
# Товары для детей и игрушки  0.36    0.07
# Автомобили                  0.73    0.04
# mean                        0.47    0.04

# %%
metrics_nmf_rf - metrics_svd_rf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.02           0.01    0.09       -0.01
# Мебель и интерьер               -0.02          -0.16    0.25        0.06
# Бытовая техника                 -0.84          -0.20   -0.08       -0.06
# Предложение услуг                0.05          -0.01   -0.08       -0.01
# Детская одежда и обувь           0.20           0.01    0.01        0.00
# Телефоны                        -0.08           0.02    0.20        0.06
# Ремонт и строительство           0.15           0.11   -0.07        0.01
# Квартиры                        -0.01          -0.02    0.05       -0.02
# Товары для детей и игрушки       0.13          -0.01    0.13       -0.01
# Автомобили                       0.10           0.02    0.08        0.02
# mean                            -0.03          -0.02    0.05        0.01
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.01    0.01
# Мебель и интерьер           0.34    0.05
# Бытовая техника            -0.14   -0.10
# Предложение услуг          -0.03    0.01
# Детская одежда и обувь      0.12    0.01
# Телефоны                    0.13    0.03
# Ремонт и строительство     -0.10    0.01
# Квартиры                    0.02    0.00
# Товары для детей и игрушки  0.16   -0.02
# Автомобили                  0.08    0.00
# mean                        0.06    0.00

# %% [markdown]
# По F-мере чуть лучше NMF.

# %% [markdown]
# **ExtraTreesClassifier**

# %%
pipeline_nmf_et = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=7, max_df=0.4)),
    ('nmf', NMF(100)),
    ('clf', ExtraTreesClassifier(n_estimators = 50, max_depth=5))
])

pipeline_svd_et = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=7, max_df=0.4)),
    ('svd', TruncatedSVD(100)),
    ('clf', ExtraTreesClassifier(n_estimators = 50, max_depth=5))
])

# %%
metrics_nmf_et, errors_bow_et = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_et)
metrics_svd_et, errors_svd_et = eval_table(data['description_norm'], data['category_name'], pipeline_svd_et)

# %%
metrics_nmf_et
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.35           0.05    0.82        0.08
# Мебель и интерьер                0.00           0.00    0.00        0.00
# Бытовая техника                  0.00           0.00    0.00        0.00
# Предложение услуг                0.24           0.37    0.01        0.01
# Детская одежда и обувь           0.44           0.10    0.56        0.05
# Телефоны                         1.00           0.00    0.06        0.03
# Ремонт и строительство           0.17           0.41    0.01        0.01
# Квартиры                         0.96           0.02    0.64        0.10
# Товары для детей и игрушки       0.95           0.06    0.07        0.04
# Автомобили                       1.00           0.00    0.12        0.05
# mean                             0.51           0.10    0.23        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.49    0.03
# Мебель и интерьер           0.00    0.00
# Бытовая техника             0.00    0.00
# Предложение услуг           0.02    0.02
# Детская одежда и обувь      0.49    0.05
# Телефоны                    0.12    0.05
# Ремонт и строительство      0.01    0.03
# Квартиры                    0.77    0.06
# Товары для детей и игрушки  0.13    0.07
# Автомобили                  0.21    0.08
# mean                        0.22    0.04

# %%
metrics_svd_et
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.34           0.01    0.78        0.05
# Мебель и интерьер                0.33           0.52    0.01        0.01
# Бытовая техника                  0.80           0.40    0.04        0.03
# Предложение услуг                0.17           0.41    0.00        0.01
# Детская одежда и обувь           0.37           0.03    0.59        0.02
# Телефоны                         1.00           0.00    0.06        0.02
# Ремонт и строительство           0.82           0.22    0.03        0.01
# Квартиры                         0.83           0.08    0.25        0.06
# Товары для детей и игрушки       0.78           0.29    0.03        0.02
# Автомобили                       0.98           0.06    0.06        0.02
# mean                             0.64           0.20    0.18        0.02
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.47    0.01
# Мебель и интерьер           0.01    0.02
# Бытовая техника             0.07    0.05
# Предложение услуг           0.01    0.02
# Детская одежда и обувь      0.45    0.02
# Телефоны                    0.11    0.04
# Ремонт и строительство      0.05    0.03
# Квартиры                    0.38    0.07
# Товары для детей и игрушки  0.07    0.04
# Автомобили                  0.11    0.04
# mean                        0.17    0.03

# %%
metrics_nmf_et - metrics_svd_et
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.01           0.04    0.04        0.03
# Мебель и интерьер               -0.33          -0.52   -0.01       -0.01
# Бытовая техника                 -0.80          -0.40   -0.04       -0.03
# Предложение услуг                0.07          -0.04    0.01        0.00
# Детская одежда и обувь           0.07           0.07   -0.03        0.03
# Телефоны                         0.00           0.00    0.00        0.01
# Ремонт и строительство          -0.65           0.19   -0.02        0.00
# Квартиры                         0.13          -0.06    0.39        0.04
# Товары для детей и игрушки       0.17          -0.23    0.04        0.02
# Автомобили                       0.02          -0.06    0.06        0.03
# mean                            -0.13          -0.10    0.05        0.02
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.02    0.02
# Мебель и интерьер          -0.01   -0.02
# Бытовая техника            -0.07   -0.05
# Предложение услуг           0.01    0.00
# Детская одежда и обувь      0.04    0.03
# Телефоны                    0.01    0.01
# Ремонт и строительство     -0.04    0.00
# Квартиры                    0.39   -0.01
# Товары для детей и игрушки  0.06    0.03
# Автомобили                  0.10    0.04
# mean                        0.05    0.01

# %% [markdown]
# По F-мере незначительно лучше NMF.

# %% [markdown]
# ### Задание № 2 (6 баллов)

# %% [markdown]
# В Gensim тоже можно добавить нграммы и tfidf. Постройте 1 модель без них (как в семинаре) и еще 3 модели (1 с нграммами, 1 с tfidf и 1 с нграммами и с tfidf). Сранивте качество с помощью метрик (перплексия, когерентность) и на глаз. Определите лучшую модель. Для каждой модели выберите 1 самую красивую на ваш взгляд тему.
#
# Используйте данные википедии из семинара. Можете взять поменьше данных, если все обучается долго.
#
# Важное требование - получившиеся модели не должны быть совсем плохими. Если хороших тем не получается, попробуйте настроить гиперпараметры, отфильтровать словарь по-другому.

# %% [markdown]
# **Обычная модель**

# %%
texts = open('wiki_data.txt', encoding='utf-8').read().splitlines()[:5000]
texts = ([normalize(text) for text in texts])

# %%
texts = [text.split() for text in texts]

# %%
dictionary = gensim.corpora.Dictionary(texts)
dictionary.filter_extremes(no_above=0.1, no_below=10)
dictionary.compactify()

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = gensim.models.LdaMulticore(corpus, 
                                 100,
                                 alpha='asymmetric',
                                 id2word=dictionary, 
                                 passes=10)

# %%
lda.print_topics()
# Out:
# [(99,
#   '0.013*"доска" + 0.008*"пение" + 0.006*"школа" + 0.006*"тропа" + 0.006*"памятник" + 0.005*"голосование" + 0.005*"сша" + 0.005*"скульптор" + 0.005*"нидерландский" + 0.005*"премьер-министр"'),
#  (98,
#   '0.057*"река" + 0.041*"км" + 0.039*"озеро" + 0.032*"берег" + 0.013*"сельский" + 0.012*"поселение" + 0.010*"высота" + 0.010*"численность" + 0.009*"флаг" + 0.009*"иметься"'),
#  (97,
#   '0.028*"университет" + 0.015*"строительство" + 0.009*"мост" + 0.009*"здание" + 0.008*"студент" + 0.008*"проект" + 0.007*"общество" + 0.007*"рубль" + 0.007*"дом" + 0.006*"построить"'),
#  (96,
#   '0.038*"театр" + 0.014*"сергей" + 0.014*"александр" + 0.012*"дом" + 0.010*"московский" + 0.010*"москва" + 0.009*"дмитрий" + 0.009*"русский" + 0.009*"театральный" + 0.008*"спектакль"'),
#  (95,
#   '0.014*"штат" + 0.009*"опера" + 0.008*"партия" + 0.007*"задание" + 0.006*"оперный" + 0.006*"способность" + 0.005*"предприятие" + 0.005*"телеканал" + 0.005*"сеть" + 0.004*"италия"'),
#  (94,
#   '0.026*"казахский" + 0.024*"сср" + 0.023*"ссср" + 0.018*"юстиция" + 0.017*"агава" + 0.016*"уругвай" + 0.015*"министр" + 0.014*"казахстан" + 0.012*"лагерь" + 0.012*"алма-ата"'),
#  (93,
#   '0.026*"метр" + 0.024*"дистанция" + 0.023*"олимпиада" + 0.013*"чемпион" + 0.012*"стена" + 0.011*"зимний" + 0.011*"собор" + 0.011*"серебряный" + 0.010*"дворец" + 0.009*"секунда"'),
#  (91,
#   '0.016*"день" + 0.015*"венгерский" + 0.013*"шотландия" + 0.013*"румыния" + 0.010*"румынский" + 0.010*"украинский" + 0.009*"шотландский" + 0.008*"нил" + 0.008*"подарок" + 0.008*"венгрия"'),
#  (92,
#   '0.015*"корабль" + 0.015*"компания" + 0.009*"система" + 0.009*"экспедиция" + 0.008*"космический" + 0.006*"испытание" + 0.006*"км" + 0.006*"около" + 0.006*"производство" + 0.005*"станция"'),
#  (90,
#   '0.022*"военный" + 0.013*"кладбище" + 0.011*"литовский" + 0.011*"должность" + 0.010*"суд" + 0.009*"великий" + 0.008*"армия" + 0.007*"эстония" + 0.007*"установить" + 0.007*"израиль"'),
#  (9,
#   '0.009*"пересыхать" + 0.009*"округ" + 0.009*"запруда" + 0.008*"самара" + 0.008*"км" + 0.006*"дом" + 0.006*"железный" + 0.006*"самарский" + 0.006*"собака" + 0.006*"ботсвана"'),
#  (8,
#   '0.010*"труба" + 0.010*"библиотека" + 0.010*"листоед" + 0.008*"microsoft" + 0.008*"иисус" + 0.007*"формула" + 0.007*"версия" + 0.006*"школа" + 0.005*"система" + 0.004*"каждый"'),
#  (7,
#   '0.023*"ростовский" + 0.021*"хутор" + 0.020*"памятник" + 0.016*"охрана" + 0.013*"поселение" + 0.012*"культура" + 0.012*"дорога" + 0.012*"государственный" + 0.012*"объект" + 0.011*"курган"'),
#  (6,
#   '0.014*"крыло" + 0.014*"цвет" + 0.013*"пятно" + 0.011*"фамилия" + 0.009*"чёрный" + 0.007*"музей" + 0.007*"красный" + 0.007*"белый" + 0.007*"форма" + 0.006*"самец"'),
#  (5,
#   '0.098*"летний" + 0.044*"спортсмен" + 0.039*"ни" + 0.038*"женщина" + 0.037*"сборная" + 0.031*"зимний" + 0.017*"соревнование" + 0.014*"мужчина" + 0.013*"1988" + 0.012*"бронзовый"'),
#  (4,
#   '0.022*"президент" + 0.016*"министр" + 0.013*"пост" + 0.012*"совет" + 0.010*"член" + 0.010*"правительство" + 0.010*"национальный" + 0.009*"должность" + 0.008*"томас" + 0.008*"республика"'),
#  (3,
#   '0.023*"книга" + 0.015*"университет" + 0.012*"газета" + 0.011*"писатель" + 0.010*"язык" + 0.009*"автор" + 0.009*"журнал" + 0.009*"роман" + 0.008*"опубликовать" + 0.008*"поэт"'),
#  (2,
#   '0.015*"партия" + 0.009*"правительство" + 0.007*"политический" + 0.006*"власть" + 0.005*"политика" + 0.005*"против" + 0.004*"движение" + 0.004*"право" + 0.004*"организация" + 0.004*"выборы"'),
#  (1,
#   '0.015*"парк" + 0.015*"брак" + 0.010*"тропический" + 0.008*"река" + 0.007*"национальный" + 0.006*"уровень" + 0.006*"шторм" + 0.006*"гора" + 0.005*"канада" + 0.005*"коммуна"'),
#  (0,
#   '0.131*"житомирский" + 0.062*"почтовый" + 0.055*"км²" + 0.054*"индекс" + 0.054*"телефонный" + 0.054*"р-н" + 0.048*"ул" + 0.044*"коатуа" + 0.024*"радомышльский" + 0.020*"романовский"')]

# %% [markdown]
# **Модель с n-граммами**

# %%
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4)
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]

# %%
dictionary_ngram = gensim.corpora.Dictionary(ngrammed_texts)
dictionary_ngram.filter_extremes(no_above=0.1, no_below=10)
dictionary_ngram.compactify()

# %%
corpus_ngrams = [dictionary_ngram.doc2bow(text) for text in texts]

# %%
lda_ngrams = gensim.models.LdaMulticore(corpus, 
                                        100,
                                        alpha='asymmetric',
                                        id2word=dictionary, 
                                        passes=10)

# %%
lda_ngrams.print_topics()
# Out:
# [(99,
#   '0.030*"военный" + 0.020*"суд" + 0.017*"ян" + 0.014*"должность" + 0.013*"лихтенштейн" + 0.013*"прокурор" + 0.011*"судья" + 0.011*"прокуратура" + 0.011*"израиль" + 0.010*"главное"'),
#  (97,
#   '0.029*"церковь" + 0.021*"храм" + 0.014*"памятник" + 0.013*"епархия" + 0.012*"собор" + 0.012*"здание" + 0.011*"культура" + 0.011*"епископ" + 0.010*"православный" + 0.009*"религиозный"'),
#  (98,
#   '0.054*"волость" + 0.023*"1-й" + 0.018*"брянский" + 0.014*"2-й" + 0.013*"венесуэла" + 0.011*"уезд" + 0.011*"образовать" + 0.011*"1977" + 0.011*"округ" + 0.010*"1978"'),
#  (96,
#   '0.029*"смотреть" + 0.025*"длина" + 0.023*"мм" + 0.016*"лист" + 0.016*"диаметр" + 0.015*"дерево" + 0.014*"высота" + 0.014*"эвкалипт" + 0.011*"ширина" + 0.011*"семейство"'),
#  (95,
#   '0.018*"игрок" + 0.015*"уровень" + 0.014*"угол" + 0.010*"каждый" + 0.009*"приём" + 0.008*"направление" + 0.008*"измерение" + 0.007*"игровой" + 0.007*"способ" + 0.007*"друг"'),
#  (93,
#   '0.065*"зимний" + 0.020*"1994" + 0.016*"2006" + 0.016*"чили" + 0.010*"турин" + 0.009*"ни" + 0.009*"норвегия" + 0.009*"таблица" + 0.008*"калгари" + 0.007*"александр"'),
#  (94,
#   '0.093*"университет" + 0.020*"студент" + 0.019*"факультет" + 0.015*"колледж" + 0.013*"якутский" + 0.012*"образование" + 0.012*"протекать" + 0.012*"запруда" + 0.011*"пересыхать" + 0.010*"наука"'),
#  (92,
#   '0.016*"клуб" + 0.009*"играть" + 0.007*"иванович" + 0.006*"дворянский" + 0.006*"александр" + 0.006*"команда" + 0.006*"выступать" + 0.005*"ссср" + 0.005*"владимир" + 0.005*"турнир"'),
#  (91,
#   '0.043*"ружинский" + 0.026*"звезда" + 0.019*"4138" + 0.009*"класс" + 0.008*"степень" + 0.007*"раставица" + 0.007*"наградить" + 0.007*"назначить" + 0.006*"орден" + 0.006*"лукаш"'),
#  (90,
#   '0.017*"российский" + 0.014*"государственный" + 0.013*"россия" + 0.011*"заместитель" + 0.011*"председатель" + 0.011*"институт" + 0.010*"наука" + 0.010*"директор" + 0.010*"член" + 0.009*"университет"'),
#  (9,
#   '0.020*"остров" + 0.015*"канада" + 0.008*"южный" + 0.008*"северный" + 0.007*"период" + 0.007*"около" + 0.007*"крупный" + 0.006*"залив" + 0.006*"самый" + 0.005*"пещера"'),
#  (8,
#   '0.050*"уезд" + 0.033*"губерния" + 0.029*"км" + 0.026*"совет" + 0.025*"река" + 0.023*"харьковский" + 0.023*"волость" + 0.021*"расстояние" + 0.020*"сельский" + 0.020*"нижегородский"'),
#  (7,
#   '0.016*"длина" + 0.015*"вода" + 0.009*"голова" + 0.008*"рыба" + 0.008*"крупный" + 0.008*"озеро" + 0.008*"встречаться" + 0.008*"семейство" + 0.008*"форма" + 0.007*"хвост"'),
#  (6,
#   '0.006*"греческий" + 0.005*"царь" + 0.005*"марка" + 0.004*"михаил" + 0.004*"хозяин" + 0.004*"войско" + 0.004*"называть" + 0.004*"слово" + 0.003*"поражение" + 0.003*"состоять"'),
#  (5,
#   '0.148*"житомирский" + 0.064*"почтовый" + 0.063*"км²" + 0.062*"индекс" + 0.061*"телефонный" + 0.061*"р-н" + 0.055*"ул" + 0.050*"коатуа" + 0.027*"радомышльский" + 0.022*"романовский"'),
#  (4,
#   '0.015*"израиль" + 0.014*"польша" + 0.012*"иордания" + 0.010*"польский" + 0.008*"китайский" + 0.008*"германия" + 0.007*"2002" + 0.006*"флот" + 0.006*"западный" + 0.006*"китай"'),
#  (3,
#   '0.008*"н" + 0.007*"экспедиция" + 0.005*"…" + 0.005*"я" + 0.005*"земля" + 0.004*"азербайджанский" + 0.004*"екатерина" + 0.004*"казак" + 0.004*"э" + 0.004*"дом"'),
#  (2,
#   '0.021*"1984" + 0.015*"боливия" + 0.014*"мексика" + 0.013*"мехико" + 0.012*"сша" + 0.011*"малайзия" + 0.011*"бирма" + 0.010*"седьмой" + 0.008*"1968" + 0.007*"имаго"'),
#  (1,
#   '0.022*"самолёт" + 0.009*"озеро" + 0.008*"крест" + 0.008*"аэродром" + 0.006*"ноябрь" + 0.006*"наградить" + 0.005*"1944" + 0.005*"полёт" + 0.005*"пилот" + 0.005*"погибнуть"'),
#  (0,
#   '0.011*"подсемейство" + 0.010*"альбом" + 0.010*"билет" + 0.008*"сингл" + 0.008*"the" + 0.007*"песня" + 0.007*"cryptocephalus" + 0.006*"сторона" + 0.006*"выпустить" + 0.005*"листоед"')]

# %% [markdown]
# **Модель с tf-idf**

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary, )
corpus_tfidf = tfidf[corpus]

# %%
lda_tfidf = gensim.models.LdaMulticore(corpus_tfidf, 
                                        100,
                                        alpha='asymmetric',
                                        id2word=dictionary, 
                                        passes=10)

# %%
lda_tfidf.print_topics()
# Out:
# [(99,
#   '0.000*"рыцарский" + 0.000*"крест" + 0.000*"командир" + 0.000*"1944" + 0.000*"дубовый" + 0.000*"танковый" + 0.000*"наградить" + 0.000*"бой" + 0.000*"генерал-майор" + 0.000*"вернер"'),
#  (98,
#   '0.000*"хабаровский" + 0.000*"культура" + 0.000*"еврейский" + 0.000*"керамика" + 0.000*"э" + 0.000*"пещера" + 0.000*"регион" + 0.000*"автономный" + 0.000*"александр" + 0.000*"назад"'),
#  (97,
#   '0.009*"белград" + 0.000*"тим" + 0.000*"университет" + 0.000*"концлагерь" + 0.000*"грузовик" + 0.000*"лагерь" + 0.000*"ричард" + 0.000*"де" + 0.000*"снаряд" + 0.000*"ирландия"'),
#  (96,
#   '0.071*"полюс" + 0.000*"епархия" + 0.000*"нью-йоркский" + 0.000*"экспедиция" + 0.000*"руб" + 0.000*"собака" + 0.000*"церковь" + 0.000*"я" + 0.000*"кинокритик" + 0.000*"york"'),
#  (94,
#   '0.026*"файл" + 0.006*"вставка" + 0.003*"директива" + 0.000*"цикл" + 0.000*"беженец" + 0.000*"сериал" + 0.000*"параметр" + 0.000*"сыграть" + 0.000*"оон" + 0.000*"альбом"'),
#  (95,
#   '0.001*"переходный" + 0.000*"мост" + 0.000*"хутор" + 0.000*"организм" + 0.000*"опора" + 0.000*"форма" + 0.000*"переход" + 0.000*"рубль" + 0.000*"предок" + 0.000*"млрд"'),
#  (93,
#   '0.000*"диск" + 0.000*"личинка" + 0.000*"хозяин" + 0.000*"рыба" + 0.000*"редкий" + 0.000*"краевой" + 0.000*"передний" + 0.000*"различие" + 0.000*"система" + 0.000*"задний"'),
#  (92,
#   '0.000*"продажа" + 0.000*"противоречить" + 0.000*"пребывание" + 0.000*"признанный" + 0.000*"принудительный" + 0.000*"прогресс" + 0.000*"поправка" + 0.000*"противоречие" + 0.000*"смертный" + 0.000*"рассмотрение"'),
#  (91,
#   '0.000*"одесский" + 0.000*"степан" + 0.000*"союз" + 0.000*"одесса" + 0.000*"жестокий" + 0.000*"организация" + 0.000*"всеукраинский" + 0.000*"виктор" + 0.000*"демократия" + 0.000*"анатолиевич"'),
#  (90,
#   '0.001*"эскадра" + 0.000*"адмирал" + 0.000*"средиземноморский" + 0.000*"неаполь" + 0.000*"фрегат" + 0.000*"корабль" + 0.000*"певица" + 0.000*"линейный" + 0.000*"оперный" + 0.000*"италия"'),
#  (9,
#   '0.067*"лихтенштейн" + 0.046*"белокалитвинский" + 0.020*"смирнов" + 0.017*"вилла" + 0.016*"коста-рика" + 0.010*"охотник" + 0.009*"категория" + 0.007*"ухо" + 0.007*"ветеринарный" + 0.004*"шторм"'),
#  (8,
#   '0.019*"1-2-й" + 0.018*"иван" + 0.008*"устройство" + 0.008*"типовой" + 0.007*"васильев" + 0.001*"манила" + 0.001*"шпицберген" + 0.001*"геологический" + 0.000*"филадельфия" + 0.000*"челюсть"'),
#  (7,
#   '0.082*"боливия" + 0.031*"пл" + 0.018*"мур" + 0.017*"балет" + 0.012*"денис" + 0.009*"петров" + 0.008*"понятие" + 0.008*"шарлотта" + 0.008*"цска" + 0.007*"my"'),
#  (6,
#   '0.047*"брянский" + 0.029*"герб" + 0.023*"флаг" + 0.019*"символ" + 0.019*"арена" + 0.016*"муниципальный" + 0.013*"детройт" + 0.013*"уравнение" + 0.008*"символизировать" + 0.008*"геральдический"'),
#  (5,
#   '0.024*"атом" + 0.024*"вагон" + 0.015*"дмитрий" + 0.014*"сергей" + 0.013*"кузнецов" + 0.011*"пионерский" + 0.010*"кирпичный" + 0.009*"темнота" + 0.007*"социал-демократ" + 0.007*"спектр"'),
#  (4,
#   '0.044*"литература" + 0.038*"дубовский" + 0.024*"обл" + 0.021*"аул" + 0.016*"хутор" + 0.016*"казахский" + 0.014*"ташкент" + 0.013*"красноярск" + 0.012*"алма-ата" + 0.011*"сср"'),
#  (3,
#   '0.132*"подсемейство" + 0.063*"семейство" + 0.036*"жук" + 0.031*"род" + 0.021*"кормовой" + 0.019*"населять" + 0.019*"иордания" + 0.018*"растение" + 0.018*"гвинея" + 0.015*"гуго"'),
#  (2,
#   '0.022*"весёловский" + 0.020*"симфония" + 0.019*"киргизия" + 0.018*"samsung" + 0.016*"эсминец" + 0.016*"киргизский" + 0.015*"миноносец" + 0.014*"крейсер" + 0.013*"корабль" + 0.011*"антенна"'),
#  (1,
#   '0.023*"летний" + 0.015*"зимний" + 0.011*"ни" + 0.011*"альбом" + 0.010*"сборная" + 0.009*"женщина" + 0.009*"спортсмен" + 0.008*"фамилия" + 0.006*"фильм" + 0.006*"песня"'),
#  (0,
#   '0.005*"житомирский" + 0.003*"км²" + 0.002*"почтовый" + 0.002*"индекс" + 0.002*"р-н" + 0.002*"телефонный" + 0.002*"коатуа" + 0.002*"ул" + 0.002*"остров" + 0.002*"км"')]

# %% [markdown]
# **Модель с n-граммами и tf-idf**

# %%
corpus_ngrams_tfidf = tfidf[corpus_ngrams]

# %%
lda_ngrams_tfidf = gensim.models.LdaMulticore(corpus, 
                                        100,
                                        alpha='asymmetric',
                                        id2word=dictionary, 
                                        passes=10)

# %%
lda_ngrams_tfidf.print_topics()
# Out:
# [(99,
#   '0.021*"билет" + 0.011*"портрет" + 0.011*"выпуск" + 0.011*"рубль" + 0.009*"образец" + 0.008*"печать" + 0.008*"сторона" + 0.008*"знак" + 0.007*"макс" + 0.007*"серия"'),
#  (98,
#   '0.032*"лагерь" + 0.018*"проведение" + 0.015*"№" + 0.015*"ярославль" + 0.012*"ян" + 0.011*"заключить" + 0.010*"дата" + 0.010*"концентрационный" + 0.009*"акция" + 0.008*"городской"'),
#  (97,
#   '0.040*"музей" + 0.023*"дом" + 0.014*"художник" + 0.012*"искусство" + 0.012*"улица" + 0.012*"н" + 0.011*"произведение" + 0.010*"здание" + 0.009*"москва" + 0.009*"общество"'),
#  (96,
#   '0.029*"снукер" + 0.026*"lotus" + 0.020*"литературный" + 0.019*"писатель" + 0.013*"одесский" + 0.012*"одесса" + 0.012*"союз" + 0.011*"чемпионат" + 0.010*"профессиональный" + 0.009*"английский"'),
#  (95,
#   '0.021*"россия" + 0.011*"российский" + 0.009*"опера" + 0.009*"премия" + 0.008*"экономический" + 0.008*"смит" + 0.007*"международный" + 0.007*"общество" + 0.007*"музыкальный" + 0.007*"школа"'),
#  (94,
#   '0.058*"князь" + 0.027*"василий" + 0.027*"великий" + 0.023*"иван" + 0.018*"василиевич" + 0.013*"сын" + 0.013*"иванович" + 0.013*"брат" + 0.012*"княжество" + 0.011*"дмитрий"'),
#  (93,
#   '0.057*"посёлок" + 0.021*"станица" + 0.015*"житель" + 0.012*"км" + 0.012*"ростовский" + 0.009*"багамский" + 0.009*"танец" + 0.009*"аксайский" + 0.009*"хозяйство" + 0.009*"остров"'),
#  (92,
#   '0.024*"храм" + 0.023*"собор" + 0.018*"монастырь" + 0.015*"здание" + 0.013*"строительство" + 0.011*"епархия" + 0.009*"святой" + 0.009*"построить" + 0.008*"церковь" + 0.007*"памятник"'),
#  (91,
#   '0.017*"звезда" + 0.013*"экспедиция" + 0.009*"въезд" + 0.008*"россия" + 0.008*"гражданин" + 0.006*"университет" + 0.006*"власть" + 0.006*"режим" + 0.006*"солнце" + 0.006*"система"'),
#  (90,
#   '0.025*"животное" + 0.022*"собака" + 0.008*"состояние" + 0.008*"бог" + 0.008*"психический" + 0.008*"задача" + 0.007*"поведение" + 0.007*"способность" + 0.006*"ребёнок" + 0.006*"теория"'),
#  (9,
#   '0.013*"пролив" + 0.009*"семейство" + 0.007*"рыба" + 0.007*"константиновский" + 0.007*"около" + 0.006*"еврей" + 0.006*"личинка" + 0.006*"обитать" + 0.006*"западный" + 0.005*"включать"'),
#  (8,
#   '0.016*"премия" + 0.010*"эпизод" + 0.010*"the" + 0.009*"фильм" + 0.008*"роль" + 0.008*"сценарий" + 0.007*"номинация" + 0.006*"я" + 0.006*"доктор" + 0.006*"сериал"'),
#  (7,
#   '0.022*"мост" + 0.013*"cryptocephalus" + 0.009*"рубль" + 0.008*"улица" + 0.008*"ким" + 0.008*"опора" + 0.007*"проект" + 0.007*"северный" + 0.006*"китай" + 0.006*"подсемейство"'),
#  (6,
#   '0.013*"общество" + 0.011*"озеро" + 0.010*"проект" + 0.009*"киев" + 0.007*"киевский" + 0.006*"сша" + 0.005*"атом" + 0.005*"звание" + 0.005*"физический" + 0.005*"мост"'),
#  (5,
#   '0.078*"летний" + 0.041*"спортсмен" + 0.033*"сборная" + 0.033*"зимний" + 0.032*"ни" + 0.031*"женщина" + 0.020*"соревнование" + 0.015*"бронзовый" + 0.014*"серебряный" + 0.011*"мужчина"'),
#  (4,
#   '0.028*"парк" + 0.014*"завод" + 0.011*"национальный" + 0.011*"оптический" + 0.007*"стекло" + 0.006*"вулкан" + 0.005*"непал" + 0.005*"кладбище" + 0.004*"библиотека" + 0.004*"игорь"'),
#  (3,
#   '0.007*"книга" + 0.005*"россия" + 0.003*"проект" + 0.003*"организация" + 0.003*"право" + 0.003*"отношение" + 0.003*"российский" + 0.003*"система" + 0.003*"случай" + 0.003*"ряд"'),
#  (2,
#   '0.006*"убить" + 0.005*"чтобы" + 0.004*"отряд" + 0.004*"английский" + 0.004*"день" + 0.004*"помощь" + 0.003*"военный" + 0.003*"флот" + 0.003*"армия" + 0.003*"корабль"'),
#  (1,
#   '0.085*"уезд" + 0.037*"округ" + 0.033*"городской" + 0.022*"специальный" + 0.016*"власть" + 0.014*"переименовать" + 0.013*"кнр" + 0.012*"империя" + 0.011*"преобразовать" + 0.010*"образовать"'),
#  (0,
#   '0.011*"строительство" + 0.010*"марка" + 0.008*"линия" + 0.007*"улица" + 0.006*"почтовый" + 0.006*"тыс" + 0.005*"железный" + 0.005*"станция" + 0.005*"железнодорожный" + 0.005*"предприятие"')]

# %% [markdown]
# **Сравнение результатов по метрикам**

# %%
def coherence(lda):
    topics = []
    for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
        topic = [word for word, _ in topic]
        topics.append(topic)
        
    coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictionary, coherence='c_v')
    return coherence_model_lda.get_coherence()

# %%
def perplexity(corpus, lda):
    return np.exp2(-lda.log_perplexity(corpus[:1000]))

# %%
comparison = pd.DataFrame()
comparison['Обычная модель'] = [perplexity(corpus, lda), coherence(lda)]
comparison['N-gramms'] = [perplexity(corpus, lda_ngrams), coherence(lda_ngrams)]
comparison['Tf-idf'] = [perplexity(corpus, lda_tfidf), coherence(lda_tfidf)]
comparison['N-gramms_tf_idf'] = [perplexity(corpus, lda_ngrams_tfidf), coherence(lda_ngrams_tfidf)]

# %%
comparison.rename({0 : 'Перплексия', 1: 'Когерентность'}).apply(lambda x: round(x, 3))
# Out:
#                Обычная модель  N-gramms    Tf-idf  N-gramms_tf_idf
# Перплексия           5631.453  5612.887  1881.794         5579.385
# Когерентность           0.536     0.525     0.384            0.547

# %% [markdown]
# **Самые красивые темы**

# %% [markdown]
# *Обычная модель (тема - политика)*:

# %%
lda.print_topics()[-3]
# Out:
# (2,
#  '0.015*"партия" + 0.009*"правительство" + 0.007*"политический" + 0.006*"власть" + 0.005*"политика" + 0.005*"против" + 0.004*"движение" + 0.004*"право" + 0.004*"организация" + 0.004*"выборы"')

# %% [markdown]
# *Модель с n-граммами (тема - религия)*:

# %%
lda_ngrams.print_topics()[1]
# Out:
# (97,
#  '0.029*"церковь" + 0.021*"храм" + 0.014*"памятник" + 0.013*"епархия" + 0.012*"собор" + 0.012*"здание" + 0.011*"культура" + 0.011*"епископ" + 0.010*"православный" + 0.009*"религиозный"')

# %% [markdown]
# *Модель с tf-ifd (тема - война, армия)*:

# %%
lda_tfidf.print_topics()[0]
# Out:
# (99,
#  '0.000*"рыцарский" + 0.000*"крест" + 0.000*"командир" + 0.000*"1944" + 0.000*"дубовый" + 0.000*"танковый" + 0.000*"наградить" + 0.000*"бой" + 0.000*"генерал-майор" + 0.000*"вернер"')

# %% [markdown]
# *Модель с n-граммами и tf-idf (тема - типография)*:

# %%
lda_ngrams_tfidf.print_topics()[0]
# Out:
# (99,
#  '0.021*"билет" + 0.011*"портрет" + 0.011*"выпуск" + 0.011*"рубль" + 0.009*"образец" + 0.008*"печать" + 0.008*"сторона" + 0.008*"знак" + 0.007*"макс" + 0.007*"серия"')

# %% [markdown]
# **Лучшая модель**

# %% [markdown]
# Каждая из моделей выдает одну или несколько адекватных тем. Если смотреть глазами, выбрать лучшую сложно.
# С учетом метрик я бы сказал, что с небольшим отрывом побеждает модель с n-граммами и tf-idf.
