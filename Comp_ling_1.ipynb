# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## 1. Задание на удаление тегов (2 балла)

# %% [markdown]
# Часто в данных, с которыми нам нужно работать помимо текста присутствует ещё какая-то лишняя информация: тэги, ссылки, код, разметка. Она, конечно, не всегда лишняя, но обычно от неё лучше избавиться.

# %% [markdown]
# Возьмем в качестве примера статью с Хабрахабра. Она скачана автоматически и в там остались некоторые тэги.

# %%
text = '''
Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично!<br><br><img src="http://img172.imageshack.us/img172/8434/18274658kc4.png" alt="Сумасшедшее яйцо"><br><br><blockquote><h3>Что это такое?</h3><br>
Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.<br>
Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).<br><br><img src="https://habrastorage.org/getpro/habr/post_images/7c7/298/33c/7c729833cd942cc493e68833e3e0f12d.jpg" alt="Тепловое отслеживание популярности"><br></blockquote><br><br><a name="habracut"></a><br><br><blockquote><h3>Для кого это?</h3><br>
Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0b0/0a0/b16/0b00a0b16b1eda28e35f39487dcd2545.jpg" alt="Отслеживание ссылок"></blockquote><br><blockquote><img src="https://habrastorage.org/getpro/habr/post_images/0b5/433/892/0b54338921665ffb5a90930147296f5b.jpg" alt="Список по популярности"><br><br>
Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).</blockquote><br><blockquote><h3>Зачем это?</h3><br>
С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет <a href="http://ttp://www.crazyegg.com" title="Сумасшедшие яйца">Сумасшедшее яйцо</a>.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/38c/af8/e75/38caf8e753782a01dc6419d3902edd57.jpg" alt="Добавление проекта"></blockquote><br><blockquote>Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0dd/3fb/b34/0dd3fbb34709e77f3fbcd6523c7eac77.jpg" alt="еще полезности"></blockquote><br><blockquote><h3>Как это работает?</h3><br>
Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/a90/e4e/e67/a90e4ee6760978463e6306a2f5982e24.jpg" alt="управление популярностью"></blockquote><br><blockquote><h3>Сколько это стоит?</h3><br>
Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации.</blockquote><br><blockquote>1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.<br><br>
2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.<br><br>
3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.<br><br>
4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.<br><br>
5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/f73/fb2/62d/f73fb262da4618a8dde67690cfd191ea.jpg" alt="Отслеживание статистики"></blockquote><br><blockquote><h3>Есть и аналоги</h3><br>
Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.</blockquote><br><blockquote> 1. <a href="https://www.google.com/analytics/home/?hl=en" title="Шикарный сбор и анализ статистики">Google Analytics</a> — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этого блога.<br><br>
2. <a href="http://www.mapsurface.com/" title="Сервис для отслеживания популярности блоков на сайте">MapSurface</a> — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. К сожалению он сейчас находится в статусе закрытой беты.</blockquote><br><blockquote><h3>Вывод</h3><br>
Использовать можно, и нужно. Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. В общем и целом — <a href="http://ttp://www.crazyegg.com">полезная вещь</a> для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.<br><br><img src="http://img241.imageshack.us/img241/2346/confettitnml5.jpg" alt="Интересная идея визуализации популярности - конфети"></blockquote><br><br>
Автор: <a href="http://www.birzool.com/" title="Я пишу о юзабилити веб интерфейсов">Ярослав Бирзул</a> (DezmASter).<br>
Источник: <a href="http://www.birzool.com/crazyegg/" title="Сумасшедшие яйца, первоисточник">Блог о юзабилити веб интерфейсов</a>.<br><br>
PS: Всех с прошедшим Новым годом! От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. Удачно вам провести время.
'''

# %%
import re

# %%
def remove_tags(text):
    clean_text = re.sub('<.+?>', ' ', text)
    clean_text = re.sub(' +', ' ', clean_text)
    clean_text = re.sub(' \.', '.', clean_text)
    clean_text = re.sub(' ,', ',', clean_text)
    clean_text = re.sub(' \n', '\n', clean_text)
    return clean_text
clean_text = remove_tags(text)
clean_text
# Out:
# '\nСегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично! Что это такое?\nКак уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.\nСервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые). Для кого это?\nРазумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.\nДа-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). Зачем это?\nС помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет Сумасшедшее яйцо. Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей. Как это работает?\nНикаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая. Сколько это стоит?\nКак я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации. 1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.\n2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.\n3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.\n4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.\n5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц. Есть и аналоги\nЯ не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользую ...

# %% [markdown]
# С помощью регулярных выражение очистите текст от тэгов (мета информацию внутри тэгов тоже удалите). В получившемся тексте точки не должны слипаться с началом следующего предложений, также не должно быть лишних пробелов.

# %% [markdown]
# ## 2. Задание на выбор слов после "не " (1 балл)
#
# Вытащите из очищенного текста все слова, которые идут после "не ", кроме слов, начинающихся на гласную букву. Сама часть "не " не должна извлекаться.

# %%
re.findall(r'\bне ([^аеёиоуэюяыАЕЁИОУЭЮЯЫ]\w+)', clean_text)
# Out:
# ['знаю',
#  'поленился',
#  'бесплатен',
#  'сайтов',
#  'нужно',
#  'лишним',
#  'нужно',
#  'потеряет',
#  'бесплатен',
#  'поленился']

# %% [markdown]
# ## 3. Задание на выбор глаголов (1 балл)
#
# Попробуйте вытащить из очищенного текста как можно больше глаголов (минимум 40 с повторениями), не перечисляя их в паттерне полностью. Можете токенизировать текст и использовать re.match, а можете использовать re.findall с \\b в начале и конце паттерна, чтобы не матчить части слов.
#
# В результате не должно быть не глаголов. Также постарайтесь сделать паттерн максимально коротким.

# %%
verbs = re.findall(r'\b\w+[ауюеи]ть?с?я?\b', clean_text)
print(verbs)
print(len(verbs))
# Out:
# ['будет', 'работает', 'Запоминается', 'позволяет', 'отслеживать', 'выводить', 'совмещает', 'Разумеется', 'пользоваться', 'может', 'дает', 'знать', 'предполагает', 'написать', 'заплатить', 'потестировать', 'отслеживать', 'хватает', 'тасовать', 'спорить', 'расположить', 'поможет', 'поможет', 'располагать', 'зайдет', 'будет', 'вычислить', 'будет', 'приносить', 'работает', 'начнет', 'работает', 'потеряет', 'стоит', 'имеет', 'Включает', 'отследить', 'Стоит', 'входит', 'подходит', 'Стоит', 'Отличается', 'Стоит', 'окупаются', 'Стоит', 'имеет', 'отследить', 'подходит', 'предлагают', 'находится', 'Использовать', 'кусаются', 'отбиваются', 'Использовать', 'помогает', 'повысить']
# 56

# %% [markdown]
# ## 4. Pymorphy vs Mystem (2 балла)

# %% [markdown]
# Лемматизируйте очищенный текст с помощью mystem и pymorphy. Сравните результаты: есть ли разница, что лучше.

# %% [markdown]
# Для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат.

# %%
from pymystem3 import Mystem
from pymorphy2 import MorphAnalyzer

# %%
mystem = Mystem()
morph = MorphAnalyzer()
analyzed = mystem.analyze(clean_text)
analyzed[:10]
# Out:
# [{'text': '\n'},
#  {'analysis': [{'lex': 'сегодняшний', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'Сегодняшняя'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заметка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'заметка'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть',
#     'wt': 0.1492564349,
#     'gr': 'V,нп=непрош,ед,изъяв,3-л'}],
#   'text': 'будет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'о', 'wt': 0.9737875835, 'gr': 'PR='}], 'text': 'о'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сервис', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'сервисе'}]

# %%
stem_tokens = [lex['text'] for lex in analyzed if lex.get('analysis')]
stem_tokens[:10]
# Out:
# ['Сегодняшняя',
#  'заметка',
#  'будет',
#  'о',
#  'сервисе',
#  'отслеживания',
#  'активности',
#  'пользователя',
#  'Я',
#  'не']

# %%
stem_lem = [lex['analysis'][0]['lex'] for lex in analyzed if lex.get('analysis')]
stem_lem[:10]
# Out:
# ['сегодняшний',
#  'заметка',
#  'быть',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  'я',
#  'не']

# %%
morph_lem = [morph.parse(token)[0][2] for token in stem_tokens]
morph_lem[:10]
# Out:
# ['сегодняшний',
#  'заметка',
#  'быть',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  'я',
#  'не']

# %%
for n in range(len(stem_lem)):
    if stem_lem[n] != morph_lem[n]:
        print(stem_tokens[n], stem_lem[n], morph_lem[n])
# Out:
# обязан обязанный обязать
# определенных определенный определённый
# данные данные дать
# активнее активно активный
# теплее тепло тёплый
# активнее активно активный
# больше много большой
# конфети конфеть конфести
# заполненнее заполненный залненный
# активнее активно активный
# все весь всё
# может может мочь
# есть быть есть
# деньги деньги деньга
# дешевых дешевый дешёвый
# выбрав выбирать выбрать
# включенными включать включить
# Точнее точно точнее
# всего все весь
# т т так
# е е быть
# того то тот
# понять понимать понять
# этого этот это
# больше много большой
# всего все весь
# Больше больше большой
# расположить располагать расположить
# им он они
# поможет помогать помочь
# поможет помогать помочь
# понять понимать понять
# лучше хорошо хороший
# всего все весь
# деньги деньги деньга
# вычислить вычислять вычислить
# наибольшую большой больший
# наименьшее маленький малый
# начнет начинать начать
# понял понимать понять
# большая большой больший
# стоит стоять стоить
# Расскажу рассказывать рассказать
# подробнее подробно подробный
# отследить отслеживать отследить
# среднего средний среднее
# Стоит стоять стоить
# включены включать включить
# все весь всё
# её она её
# этого этот это
# Стоит стоять стоить
# большие большой больший
# деньги деньги деньга
# Стоит стоять стоить
# отследить отслеживать отследить
# большим большой больший
# Есть быть есть
# собрал собирать собрать
# еще еще ещё
# дешевле дешево дешёвый
# счетчиков счетчик счётчик
# т т так
# им он они
# этого этот это
# еще еще ещё
# т т так
# предпочел предпочитать предпочесть
# врядли врядли врядлить
# собрал собирать собрать
# деньги деньги деньга
# деньги деньги деньга
# нужно нужный нужно
# повысить повышать повысить
# юзабилиста юзабилист юзабилистый
# деньгами деньги деньга
# этом этот это
# есть быть есть
# юзабилити юзабилити юзабилить
# прошедшим прошедший прошедшее
# самого самый сам
# самого самый сам
# провести проводить провести

# %% [markdown]
# * Mystem дает лемму несовершенного вида для глагольных токенов как совершенного, так и несовершенного вида (расскажу – рассказывать; отследить – отслеживать; начнет – начинать), в то время как Pymorphy – лемму совершенного вида (расскажу – рассказать; отследить – отследить; начнет – начать).
# * Mystem приводит прилагательные сравнительной степени к наречиям (активнее – активно; больше – много; точнее – точно), а Pymorphy – либо к прилагательным начальной степени (активнее – активный; больше – большой), либо к прилагательным сравнительной степени (наибольшую – больший; точнее – точнее).
# * Mystem правильно разбирает заимствования (юзабилиста – юзабилист; юзабилити – юзабилити), а Pymorphy – нет (юзабилиста – юзабилистый; юзабилити – юзабилить).
# * Pymorphy, в отличие от Mystem, умеет расшифровывать сокращения (т.е. = так быть).
# * Pymorphy различает е и ё.
# * Анализаторы по-разному разбирают местоимения: для майстема *им* – творительный падеж местоимения *он* (этот меч выкован *им*), а для пайморфи *им* – дательный падеж местоимения *они* (дать *им* денег). Правильным является вариант пайморфи: "...В этом *им* поможет Сумасшедшее яйцо...".
# * Кажется, что майстем чуть лучше по качеству в среднем, а пайморфи иногда чуть лучше разбирает сложные случаи, наподобие приведенного выше.

# %% [markdown]
# ## 5. Разбиение на предложения в Mystem (2 балла)
#
# С помощью Mystem разделите текст из первого задания (очищенный) на предложения. Сравните разбиение с razdel.sentenize

# %%
with open('text.txt', 'w', encoding = 'UTF-8') as f:
    f.write(clean_text)
# !mystem -cs --format json text.txt text_parsed.txt

# %%
import json
my_txt = [json.loads(line) for line in open('text_parsed.txt', encoding = 'UTF-8')]
sent = ''
for par in my_txt:
    for n in par:
        sent+=n['text']
mystem_sent = sent.split('\\s')
mystem_sent[:10]
# Out:
# ['\r\nСегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg. ',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. ',
#  'Запоминается? ',
#  'Отлично! ',
#  'Что это такое?\r\nКак уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.\r\nСервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые). ',
#  'Для кого это?\r\nРазумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. ',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. ',
#  'Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.\r\nДа-да, сервис не бесплатен. ',
#  'Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). ',
#  'Зачем это?\r\nС помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. ']

# %%
from razdel import sentenize
razdel_sent = [parse.text for parse in list(sentenize(clean_text))]
razdel_sent[:10]
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg.',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.',
#  'Запоминается?',
#  'Отлично!',
#  'Что это такое?',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.',
#  'Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).',
#  'Для кого это?',
#  'Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.']

# %% [markdown]
# * Mystem при разбиении на предложения не учитывает перенос строки \r\n (отсутствует тэг \\\s), поэтому для решения задачи необходимы дополнительные операции.
# * Mystem оставляет пробельные символы в конце предложений.
# * В razdel эти проблемы решены.

# %% [markdown]
# ## 6*. Дизамбигуация в Mystem (2 балла)

# %% [markdown]
# *необязательное задание на 10 баллов

# %% [markdown]
# Одна из фичей майстема - контекстная дизамбигуация (т.е. определение правильного разбора в зависимости от контекста).

# %% [markdown]
# Запустите mystem на очищенном тексте с дизамбигуацией и без и проверьте есть ли какие-то различия.

# %%
# !mystem -dc --format json text.txt disambiguation.txt
disambig = [json.loads(line) for line in open('disambiguation.txt', encoding = 'UTF-8')]
disambig
# Out:
# [[{'text': '\r\n'}],
#  [{'analysis': [{'lex': 'сегодняшний'}], 'text': 'Сегодняшняя'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заметка'}], 'text': 'заметка'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активности'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователя'},
#   {'text': ' — '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'я'}], 'text': 'Я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'знать'}], 'text': 'знаю'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обязанный'}], 'text': 'обязан'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'таким'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'говорящий'}], 'text': 'говорящим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'имя'}], 'text': 'именем'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'оно'}], 'text': 'оно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}], 'text': 'хорошо'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'запоминаться'}], 'text': 'Запоминается'},
#   {'text': '? '},
#   {'analysis': [{'lex': 'отлично'}], 'text': 'Отлично'},
#   {'text': '! '},
#   {'analysis': [{'lex': 'что'}], 'text': 'Что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'такое'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уже'}], 'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сказать'}], 'text': 'сказано'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'выше'}], 'text': 'выше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'перемещение'}], 'text': 'перемещения'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайту'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кто'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'куда'}], 'text': 'куда'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кликнуть'}], 'text': 'кликнул'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ссылка'}], 'text': 'ссылки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'популярный'}], 'text': 'популярные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тот'}], 'text': 'тому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подобный'}], 'text': 'подобная'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'разнородный'}], 'text': 'разнородная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'информация'}], 'text': 'информация'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'сервис'}], 'text': 'Сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'позволять'}], 'text': 'позволяет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'определенный'}], 'text': 'определенных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'выводить'}], 'text': 'выводить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'эти'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'данные'}], 'text': 'данные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'различный'}], 'text': 'различных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'форма'}], 'text': 'формах'},
#   {'text': ': «'},
#   {'analysis': [{'lex': 'инфракрасный'}], 'text': 'инфракрасная'},
#   {'text': '» — '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'тепло'}], 'text': 'теплее'},
#   {'text': '», '},
#   {'analysis': [{'lex': 'салют'}], 'text': 'салюты'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'много'}], 'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конфеть', 'qual': 'bastard'}], 'text': 'конфети'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'простой'}], 'text': 'простой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'список'}], 'text': 'список'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сортировка'}], 'text': 'сортировкой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активности'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'колба'}], 'text': 'колбы'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заполненный', 'qual': 'bastard'}],
#    'text': 'заполненнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'колба'}], 'text': 'колба'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'облако'}], 'text': 'облака'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'мой'}], 'text': 'мой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'взгляд'}], 'text': 'взгляд'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'удобный'}], 'text': 'удобный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вариант'}], 'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'совмещать'}], 'text': 'совмещает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}], 'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'остальной'}], 'text': 'остальные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вместе'}], 'text': 'вместе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'взять'}], 'text': 'взятые'},
#   {'text': ')'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'для'}], 'text': 'Для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'разумеется'}], 'text': 'Разумеется'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'изначально'}], 'text': 'изначально'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'планироваться'}], 'text': 'планировался'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'как'}], 'text': 'как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'первый'}], 'text': 'первый'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помощник'}], 'text': 'помощник'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользоваться'}], 'text': 'пользоваться'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'они'}], 'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'может'}], 'text': 'может'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'каждый'}], 'text': 'каждый'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньги'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'интуитивный'}], 'text': 'интуитивный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'интерфейс'}], 'text': 'интерфейс'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дизайн'}], 'text': 'дизайн'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'давать'}], 'text': 'дает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'знать'}], 'text': 'знать'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'массово'}], 'text': 'массово'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'популяризироваться'}], 'text': 'популяризировался'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пол'}], 'text': 'пол'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'год'}], 'text': 'года'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'год'}], 'text': 'год'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'назад'}], 'text': 'назад'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'относительно'}], 'text': 'Относительно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'недорогой'}], 'text': 'недорогой'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уж'}], 'text': 'уж'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'точно'}], 'text': 'точно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'из'}], 'text': 'из'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дешевый'}], 'text': 'дешевых'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предполагать'}], 'text': 'предполагает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'собой'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'платный'}], 'text': 'платных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'линия'}], 'text': 'линии'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'один'}], 'text': 'одну'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатную'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'дабы'}], 'text': 'Дабы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'написать'}], 'text': 'написать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обзор'}], 'text': 'обзор'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полениться'}], 'text': 'поленился'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заплатить'}], 'text': 'заплатить'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}], 'text': 'долларов'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': ') '},
#   {'analysis': [{'lex': 'выбирать'}], 'text': 'выбрав'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'средний'}], 'text': 'средний'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вариант'}], 'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'несколько'}], 'text': 'нескольких'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'проект'}], 'text': 'проектов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'включенными'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дополнительный'}], 'text': 'дополнительными'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'функция'}], 'text': 'функциями'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'да'}], 'text': 'Да'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'да'}], 'text': 'да'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатен'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'точно'}], 'text': 'Точнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потестировать', 'qual': 'bastard'}],
#    'text': 'потестировать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'есть'}], 'text': 'есть'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'немного'}], 'text': 'немного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обрезать'}], 'text': 'обрезана'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'text': '5000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посетитель'}], 'text': 'посетителей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}], 'text': 'всего'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'внимание'}], 'text': 'внимание'},
#   {'text': ' — '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайтов'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'е'}], 'text': 'е'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хватать'}], 'text': 'хватает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'то'}], 'text': 'того'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'чтобы'}], 'text': 'чтобы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезность'}], 'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ')'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'зачем'}], 'text': 'Зачем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'с'}], 'text': 'С'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помощь'}], 'text': 'помощью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тасовать'}], 'text': 'тасовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блок'}], 'text': 'блоки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезны'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователям'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'много'}], 'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}], 'text': 'всего'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'больше'}], 'text': 'Больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}], 'text': 'нужно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'спорить'}], 'text': 'спорить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'создатель'}], 'text': 'создателям'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блок'}], 'text': 'блок'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'располагать'}], 'text': 'расположить'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'этом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}], 'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сумасшедший'}], 'text': 'Сумасшедшее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'яйцо'}], 'text': 'яйцо'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'также'}], 'text': 'Также'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зона'}], 'text': 'зоне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}], 'text': 'лучше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}], 'text': 'всего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'располагать'}], 'text': 'располагать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'реклама'}], 'text': 'рекламу'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'когда'}], 'text': 'когда'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ваш'}], 'text': 'вашем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'речь'}], 'text': 'речь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зайти'}], 'text': 'зайдет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'монетизация', 'qual': 'bastard'}],
#    'text': 'монетизации'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'ведь'}], 'text': 'Ведь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'альтруизм'}], 'text': 'альтруизм'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}], 'text': 'хорошо'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'содержание'}], 'text': 'содержание'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужный'}], 'text': 'нужны'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лишний'}], 'text': 'лишним'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вычислять'}], 'text': 'вычислить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зона'}], 'text': 'зоны'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'реклама'}], 'text': 'реклама'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'приносить'}], 'text': 'приносить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'наибольшую'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отдача'}], 'text': 'отдачу'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'маленький'}], 'text': 'наименьшее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'раздражение'}], 'text': 'раздражение'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'никакой'}], 'text': 'Никаких'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'километровый'}], 'text': 'километровых'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'скрипт'}], 'text': 'скриптов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вставлять'}], 'text': 'вставлять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}], 'text': 'нужно'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'достаточно'}], 'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'вставиь'},
#   {'text': ' '},
#   {'text': '2'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'строчка'}], 'text': 'строчки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'яваскрипт', 'qual': 'bastard'}],
#    'text': 'яваскрипта'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'начинать'}], 'text': 'начнет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживание'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'насколько'}], 'text': 'Насколько'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понял'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'исполнительный'}], 'text': 'исполнительный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'скрипт'}], 'text': 'скрипт'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервер'}], 'text': 'сервере'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'поэтому'}], 'text': 'поэтому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ваш'}], 'text': 'ваш'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайт'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'производительность'}], 'text': 'производительности'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потерять'}], 'text': 'потеряет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ни'}], 'text': 'ни'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'секунда'}], 'text': 'секунды'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезность'}], 'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'довольно'}], 'text': 'довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'таки'}], 'text': 'таки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'большая'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'сколько'}], 'text': 'Сколько'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'стоять'}], 'text': 'стоит'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уже'}], 'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'упоминать'}], 'text': 'упоминал'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'далеко'}], 'text': 'далеко'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатен'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'хоть'}], 'text': 'хоть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'иметь'}], 'text': 'имеет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестовый'}], 'text': 'тестовую'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатную'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версию'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'рассказывать'}], 'text': 'Расскажу'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подробно'}], 'text': 'подробнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тарификация'}], 'text': 'тарификации'},
#   {'text': '. '},
#   {'text': '1'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'Бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестовый'}], 'text': 'тестовая'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версия'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'Включает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'себя'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '5'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '2'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'базовый'}], 'text': 'Базовая'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версия'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версии'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отследить'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}], 'text': 'что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'достаточно'}], 'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'средний'}], 'text': 'среднего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'корпоративный'}], 'text': 'корпоративного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'базовый'}], 'text': 'базовый'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'комплект'}], 'text': 'комплект'},
#   {'text': ' — '},
#   {'text': '9'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'комплект'}], 'text': 'комплект'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'включены'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}], 'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дополнительный'}], 'text': 'дополнительные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'функция'}], 'text': 'функции'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '3'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'стандарт'}], 'text': 'Стандарт'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'неё'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'входить'}], 'text': 'входит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '25'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'text': '20'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'Вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подходить'}], 'text': 'подходит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'новый'}], 'text': 'нового'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'стартап', 'qual': 'bastard'}], 'text': 'стартапа'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоить'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'именно'}], 'text': 'именно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'её'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'купить'}], 'text': 'купил'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'написание'}], 'text': 'написания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обзор'}], 'text': 'обзора'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '4'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'плюс'}], 'text': 'Плюс'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'отличаться'}], 'text': 'Отличается'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предыдущий'}], 'text': 'предыдущей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможностью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '100'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'text': '50'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'очень'}], 'text': 'Очень'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'тариф'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'крупный'}], 'text': 'крупных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисов'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'text': '49'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'довольно'}], 'text': 'Довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'большие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'за'}], 'text': 'за'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'они'}], 'text': 'они'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обычно'}], 'text': 'обычно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лихва'}], 'text': 'лихвой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'окупаться'}], 'text': 'окупаются'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '5'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'про'}], 'text': 'Про'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'почти'}], 'text': 'почти'},
#   {'text': ' '},
#   {'text': '100'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}], 'text': 'долларов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'иметь'}], 'text': 'имеет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отследить'},
#   {'text': ' '},
#   {'text': '250'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сто'}], 'text': 'ста'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'Тариф'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подходить'}], 'text': 'подходит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'монстр'}], 'text': 'монстров'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'большой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещаемость'}], 'text': 'посещаемостью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'большим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'количество'}], 'text': 'количеством'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'Есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналоги'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'я'}], 'text': 'Я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полениться'}], 'text': 'поленился'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'собирать'}], 'text': 'собрал'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'еще'}], 'text': 'еще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пара'}], 'text': 'пару'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ссылка'}], 'text': 'ссылок'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналогами'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предлагать'}], 'text': 'предлагают'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'такие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'же'}], 'text': 'же'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'услуга'}], 'text': 'услуги'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'немного'}], 'text': 'немного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дешево'}], 'text': 'дешевле'},
#   {'text': '. '},
#   {'text': '1'},
#   {'text': '. '},
#   {'analysis': [], 'text': 'Google'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'Analytics'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сбор'}], 'text': 'сбора'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'анализ'}], 'text': 'анализа'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статистика'}], 'text': 'статистики'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'вывод'}], 'text': 'вывод'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статистика'}], 'text': 'статистики'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наглядный'}], 'text': 'наглядной'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'форма'}], 'text': 'форме'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'без'}], 'text': 'без'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'разнообразный'}], 'text': 'разнообразных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'рейтинг'}], 'text': 'рейтингов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'счетчик'}], 'text': 'счетчиков'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'очень'}], 'text': 'Очень'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подробный'}], 'text': 'подробная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вещь'}], 'text': 'вещь'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'рекомендовать'}], 'text': 'Рекомендую'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'к'}], 'text': 'к'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сам'}], 'text': 'сам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользоваться'}], 'text': 'пользуюсь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}], 'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блог'}], 'text': 'блога'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '2'},
#   {'text': '. '},
#   {'analysis': [], 'text': 'MapSurface'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сам'}], 'text': 'сам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'еще'}], 'text': 'еще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'использовать'}], 'text': 'использовал'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'к'}], 'text': 'к'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предпочитать'}], 'text': 'предпочел'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'врядли', 'qual': 'bastard'}], 'text': 'врядли'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'будучи'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'плохой'}], 'text': 'плохим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'собирать'}], 'text': 'собрал'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бы'}], 'text': 'бы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'множество'}], 'text': 'множество'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'положительный'}], 'text': 'положительных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отзыв'}], 'text': 'отзывов'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'к'}], 'text': 'К'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сожаление'}], 'text': 'сожалению'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}], 'text': 'он'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сейчас'}], 'text': 'сейчас'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'находиться'}], 'text': 'находится'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статус'}], 'text': 'статусе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'закрытый'}], 'text': 'закрытой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бета'}], 'text': 'беты'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вывод'}], 'text': 'Вывод'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'использовать'}], 'text': 'Использовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}], 'text': 'нужно'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вот'}], 'text': 'Вот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'тарифы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'довольно'}], 'text': 'довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'больно'}], 'text': 'больно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кусаться'}], 'text': 'кусаются'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обычно'}], 'text': 'обычно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'эти'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потом'}], 'text': 'потом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лихва'}], 'text': 'лихвой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отбиваться'}], 'text': 'отбиваются'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'повышение'}], 'text': 'повышении'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конвертация'}], 'text': 'конвертации'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посетитель'}], 'text': 'посетителей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньги'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'использовать'}], 'text': 'Использовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужный'}], 'text': 'нужно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'рекламный'}], 'text': 'рекламных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'место'}], 'text': 'мест'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'удобство'}], 'text': 'удобства'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отдельный'}], 'text': 'отдельных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}], 'text': 'что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'помогает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'опять'}], 'text': 'опять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'же'}], 'text': 'же'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'повышать'}], 'text': 'повысить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конвертация'}], 'text': 'конвертацию'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'общий'}], 'text': 'общем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'целое'}], 'text': 'целом'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вещь'}], 'text': 'вещь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'каждый'}], 'text': 'каждого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'владелец'}], 'text': 'владельца'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайтов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилиста'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вообще'}], 'text': 'вообще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'практически'}], 'text': 'практически'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обязательный'}], 'text': 'обязательна'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'к'}], 'text': 'К'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'счастие'}], 'text': 'счастью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'человек'}], 'text': 'людей'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'поиздержаться'}], 'text': 'поиздержались'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}], 'text': 'деньгами'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяце'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналоги'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'автор'}], 'text': 'Автор'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'ярослав'}], 'text': 'Ярослав'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бирзула', 'qual': 'bastard'}], 'text': 'Бирзул'},
#   {'text': ' ('},
#   {'analysis': [], 'text': 'DezmASter'},
#   {'text': ')'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'источник'}], 'text': 'Источник'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'блог'}], 'text': 'Блог'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилити', 'qual': 'bastard'}], 'text': 'юзабилити'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'веб'}], 'text': 'веб'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'интерфейс'}], 'text': 'интерфейсов'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [], 'text': 'PS'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'весь'}], 'text': 'Всех'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'прошедший'}], 'text': 'прошедшим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'новый'}], 'text': 'Новым'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'год'}], 'text': 'годом'},
#   {'text': '! '},
#   {'analysis': [{'lex': 'от'}], 'text': 'От'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}], 'text': 'всей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'душа'}], 'text': 'души'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'желать'}], 'text': 'желаю'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}], 'text': 'всего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'самый'}], 'text': 'самого'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'самый'}], 'text': 'самого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'лучшего'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}], 'text': 'чего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'желать'}], 'text': 'желаете'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'самый'}], 'text': 'самых'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сокровенный'}], 'text': 'сокровенных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'мечта'}], 'text': 'мечтах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'удачно'}], 'text': 'Удачно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'проводить'}], 'text': 'провести'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'время'}], 'text': 'время'},
#   {'text': '.'},
#   {'text': '\r\n'}]]

# %%
disambig_lem = []
for p in disambig:
    for w in p:
        if "analysis" in w:
            if w["analysis"]:
                disambig_lem.append(w["analysis"][0]["lex"])
disambig_lem[:10]
# Out:
# ['сегодняшний',
#  'заметка',
#  'быть',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  'я',
#  'не']

# %%
# !mystem -c --format json text.txt ambig.txt
ambig = [json.loads(line) for line in open('ambig.txt', encoding = 'UTF-8')]
ambig
# Out:
# [[{'text': '\r\n'}],
#  [{'analysis': [{'lex': 'сегодняшний'}], 'text': 'Сегодняшняя'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заметка'}], 'text': 'заметка'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'будет'}, {'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активности'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователя'},
#   {'text': ' — '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'я'}], 'text': 'Я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'знать'}], 'text': 'знаю'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}, {'lex': 'ком'}, {'lex': 'кома'}],
#    'text': 'кому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обязанный'}, {'lex': 'обязывать'}], 'text': 'обязан'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'таким'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'говорить'}, {'lex': 'говорящий'}],
#    'text': 'говорящим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'имя'}], 'text': 'именем'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'оно'}], 'text': 'оно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}, {'lex': 'хороший'}], 'text': 'хорошо'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'запоминаться'}], 'text': 'Запоминается'},
#   {'text': '? '},
#   {'analysis': [{'lex': 'отлично'}, {'lex': 'отличный'}], 'text': 'Отлично'},
#   {'text': '! '},
#   {'analysis': [{'lex': 'что'}], 'text': 'Что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'такое'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уже'},
#     {'lex': 'узкий'},
#     {'lex': 'узко'},
#     {'lex': 'уж'}],
#    'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сказать'}], 'text': 'сказано'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'высоко'},
#     {'lex': 'высокий'},
#     {'lex': 'выше'},
#     {'lex': 'выша'}],
#    'text': 'выше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'перемещение'}], 'text': 'перемещения'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайту'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кто'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'куда'}], 'text': 'куда'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кликнуть'}], 'text': 'кликнул'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ссылка'}], 'text': 'ссылки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'популярный'}], 'text': 'популярные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'то'},
#     {'lex': 'тот'},
#     {'lex': 'тома'},
#     {'lex': 'том'}],
#    'text': 'тому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подобный'}], 'text': 'подобная'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'разнородный'}], 'text': 'разнородная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'информация'}], 'text': 'информация'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'сервис'}], 'text': 'Сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'позволять'}], 'text': 'позволяет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'определенный'}, {'lex': 'определять'}],
#    'text': 'определенных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'выводить'}, {'lex': 'вывести'}], 'text': 'выводить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'эти'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'данные'}, {'lex': 'давать'}, {'lex': 'данный'}],
#    'text': 'данные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'различный'}], 'text': 'различных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'форма'}], 'text': 'формах'},
#   {'text': ': «'},
#   {'analysis': [{'lex': 'инфракрасный'}], 'text': 'инфракрасная'},
#   {'text': '» — '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'чем'}, {'lex': 'что'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}, {'lex': 'активный'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'то'},
#     {'lex': 'тот'},
#     {'lex': 'тем'},
#     {'lex': 'тема'}],
#    'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'теплый'}, {'lex': 'тепло'}], 'text': 'теплее'},
#   {'text': '», '},
#   {'analysis': [{'lex': 'салют'}], 'text': 'салюты'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'чем'}, {'lex': 'что'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}, {'lex': 'активный'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'то'},
#     {'lex': 'тот'},
#     {'lex': 'тем'},
#     {'lex': 'тема'}],
#    'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'больше'},
#     {'lex': 'большой'},
#     {'lex': 'много'},
#     {'lex': 'больший'}],
#    'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конфеть', 'qual': 'bastard'},
#     {'lex': 'конфети', 'qual': 'bastard'},
#     {'lex': 'конфетя', 'qual': 'bastard'}],
#    'text': 'конфети'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'простой'}, {'lex': 'простаивать'}],
#    'text': 'простой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'список'}], 'text': 'список'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сортировка'}], 'text': 'сортировкой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активность'}], 'text': 'активности'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'колба'}], 'text': 'колбы'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'чем'}, {'lex': 'что'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заполненный', 'qual': 'bastard'}],
#    'text': 'заполненнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'колба'}], 'text': 'колба'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'то'},
#     {'lex': 'тот'},
#     {'lex': 'тем'},
#     {'lex': 'тема'}],
#    'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'активно'}, {'lex': 'активный'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'область'}], 'text': 'область'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'облако'}], 'text': 'облака'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'мой'}, {'lex': 'мыть'}], 'text': 'мой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'взгляд'}], 'text': 'взгляд'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'удобный'}], 'text': 'удобный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вариант'}, {'lex': 'варианта'}], 'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'совмещать'}], 'text': 'совмещает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}, {'lex': 'себе'}, {'lex': 'себ'}],
#    'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}, {'lex': 'все'}], 'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'остальной'}, {'lex': 'остальное'}],
#    'text': 'остальные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вместе'}], 'text': 'вместе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'взять'}], 'text': 'взятые'},
#   {'text': ')'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'для'}], 'text': 'Для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'разуметься'}, {'lex': 'разумеется'}],
#    'text': 'Разумеется'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'изначально'}, {'lex': 'изначальный'}],
#    'text': 'изначально'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'планироваться'}], 'text': 'планировался'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'как'}], 'text': 'как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'первый'}], 'text': 'первый'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помощник'}], 'text': 'помощник'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользоваться'}], 'text': 'пользоваться'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}, {'lex': 'оно'}, {'lex': 'они'}, {'lex': 'има'}],
#    'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'мочь'}, {'lex': 'может'}], 'text': 'может'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'каждый'}], 'text': 'каждый'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кто'}], 'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}, {'lex': 'есть'}], 'text': 'есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньги'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'интуитивный'}], 'text': 'интуитивный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'интерфейс'}], 'text': 'интерфейс'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дизайн'}], 'text': 'дизайн'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'давать'}], 'text': 'дает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}, {'lex': 'себе'}, {'lex': 'себ'}],
#    'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'знать'}], 'text': 'знать'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'массово'}, {'lex': 'массовый'}], 'text': 'массово'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'популяризироваться'}], 'text': 'популяризировался'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пол'}, {'lex': 'пола'}, {'lex': 'полый'}],
#    'text': 'пол'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'год'}], 'text': 'года'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'год'}], 'text': 'год'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'назад'}], 'text': 'назад'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'относительно'}, {'lex': 'относительный'}],
#    'text': 'Относительно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'недорогой'}], 'text': 'недорогой'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уж'}], 'text': 'уж'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'точно'}, {'lex': 'точный'}], 'text': 'точно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'из'}, {'lex': 'иза'}], 'text': 'из'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дешевый'}], 'text': 'дешевых'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предполагать'}], 'text': 'предполагает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'собой'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'платный'}], 'text': 'платных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'линия'}], 'text': 'линии'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'один'}], 'text': 'одну'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатную'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'дабы'}, {'lex': 'даба'}, {'lex': 'даб'}],
#    'text': 'Дабы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'написать'}], 'text': 'написать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обзор'}], 'text': 'обзор'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полениться'}], 'text': 'поленился'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'заплатить'}], 'text': 'заплатить'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}, {'lex': 'долларовый'}], 'text': 'долларов'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': ') '},
#   {'analysis': [{'lex': 'выбирать'}], 'text': 'выбрав'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'средний'}], 'text': 'средний'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вариант'}, {'lex': 'варианта'}], 'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'несколько'}, {'lex': 'нескольким'}],
#    'text': 'нескольких'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'проект'}], 'text': 'проектов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'включенными'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дополнительный'}], 'text': 'дополнительными'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'функция'}], 'text': 'функциями'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'да'}], 'text': 'Да'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'да'}], 'text': 'да'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатен'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'точно'}, {'lex': 'точный'}], 'text': 'Точнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потестировать', 'qual': 'bastard'}],
#    'text': 'потестировать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}, {'lex': 'есть'}], 'text': 'есть'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'немного'}, {'lex': 'немногий'}], 'text': 'немного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обрезать'}], 'text': 'обрезана'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'text': '5000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посетитель'}], 'text': 'посетителей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}, {'lex': 'всего'}, {'lex': 'весь'}],
#    'text': 'всего'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'внимание'}], 'text': 'внимание'},
#   {'text': ' — '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайтов'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'е'}], 'text': 'е'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хватать'}], 'text': 'хватает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'то'}, {'lex': 'тот'}, {'lex': 'того'}],
#    'text': 'того'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'чтобы'}], 'text': 'чтобы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезность'}], 'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ')'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'зачем'}], 'text': 'Зачем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'с'}], 'text': 'С'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помощь'}], 'text': 'помощью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тасовать'}], 'text': 'тасовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блок'}], 'text': 'блоки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезны'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователям'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'больше'},
#     {'lex': 'большой'},
#     {'lex': 'много'},
#     {'lex': 'больший'}],
#    'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}, {'lex': 'всего'}, {'lex': 'весь'}],
#    'text': 'всего'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'больше'},
#     {'lex': 'большой'},
#     {'lex': 'много'},
#     {'lex': 'больший'}],
#    'text': 'Больше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}, {'lex': 'нужный'}], 'text': 'нужно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'спорить'}], 'text': 'спорить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'создатель'}], 'text': 'создателям'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блок'}], 'text': 'блок'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'располагать'}], 'text': 'расположить'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}, {'lex': 'оно'}, {'lex': 'они'}, {'lex': 'има'}],
#    'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сумасшедший'}], 'text': 'Сумасшедшее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'яйцо'}], 'text': 'яйцо'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'также'}], 'text': 'Также'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'какой'}], 'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зона'}], 'text': 'зоне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}, {'lex': 'хороший'}], 'text': 'лучше'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}, {'lex': 'всего'}, {'lex': 'весь'}],
#    'text': 'всего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'располагать'}], 'text': 'располагать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'реклама'}], 'text': 'рекламу'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'когда'}], 'text': 'когда'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ваш'}], 'text': 'вашем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'речь'}], 'text': 'речь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зайти'}], 'text': 'зайдет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'монетизация', 'qual': 'bastard'}],
#    'text': 'монетизации'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'ведь'}], 'text': 'Ведь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'альтруизм'}], 'text': 'альтруизм'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хорошо'}, {'lex': 'хороший'}], 'text': 'хорошо'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'содержание'}], 'text': 'содержание'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужный'}], 'text': 'нужны'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лишний'}], 'text': 'лишним'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'будет'}, {'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вычислять'}], 'text': 'вычислить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'зона'}], 'text': 'зоны'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'реклама'}], 'text': 'реклама'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'будет'}, {'lex': 'быть'}], 'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'приносить'}], 'text': 'приносить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'наибольшую'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отдача'}], 'text': 'отдачу'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'маленький'}], 'text': 'наименьшее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'раздражение'}], 'text': 'раздражение'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользователь'}], 'text': 'пользователей'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'никакой'}], 'text': 'Никаких'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'километровый'}], 'text': 'километровых'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'скрипт'}], 'text': 'скриптов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вставлять'}], 'text': 'вставлять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}, {'lex': 'нужный'}], 'text': 'нужно'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'достаточно'}, {'lex': 'достаточный'}],
#    'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'вставиь'},
#   {'text': ' '},
#   {'text': '2'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'строчка'}, {'lex': 'строчок'}], 'text': 'строчки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'яваскрипт', 'qual': 'bastard'}],
#    'text': 'яваскрипта'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'начинать'}], 'text': 'начнет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживание'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'насколько'}], 'text': 'Насколько'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'понимать'}], 'text': 'понял'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'исполнительный'}], 'text': 'исполнительный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'скрипт'}], 'text': 'скрипт'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'работать'}], 'text': 'работает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервер'}], 'text': 'сервере'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'поэтому'}], 'text': 'поэтому'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ваш'}], 'text': 'ваш'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайт'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'производительность'}], 'text': 'производительности'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потерять'}], 'text': 'потеряет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ни'}], 'text': 'ни'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'секунда'}, {'lex': 'секунд'}], 'text': 'секунды'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезность'}], 'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'довольно'}, {'lex': 'довольный'}],
#    'text': 'довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'таки'}], 'text': 'таки'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}, {'lex': 'больший'}], 'text': 'большая'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'сколько'}, {'lex': 'скольким'}], 'text': 'Сколько'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'стоять'}, {'lex': 'стоить'}], 'text': 'стоит'},
#   {'text': '?'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'уже'},
#     {'lex': 'узкий'},
#     {'lex': 'узко'},
#     {'lex': 'уж'}],
#    'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'упоминать'}], 'text': 'упоминал'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'далеко'}, {'lex': 'далекий'}], 'text': 'далеко'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатен'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'хоть'}], 'text': 'хоть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'иметь'}], 'text': 'имеет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестовый'}], 'text': 'тестовую'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатную'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версию'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'рассказывать'}], 'text': 'Расскажу'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подробно'}, {'lex': 'подробный'}, {'lex': 'дробный'}],
#    'text': 'подробнее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тарификация'}], 'text': 'тарификации'},
#   {'text': '. '},
#   {'text': '1'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'Бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестовый'}], 'text': 'тестовая'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версия'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'Включает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'себя'}], 'text': 'себя'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '5'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '2'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'базовый'}], 'text': 'Базовая'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версия'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}, {'lex': 'эта'}], 'text': 'этой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'версии'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отследить'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}], 'text': 'что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'достаточно'}, {'lex': 'достаточный'}],
#    'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'средний'}, {'lex': 'среднее'}], 'text': 'среднего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'корпоративный'}], 'text': 'корпоративного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}, {'lex': 'стоить'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'базовый'}], 'text': 'базовый'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'комплект'}], 'text': 'комплект'},
#   {'text': ' — '},
#   {'text': '9'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}, {'lex': 'долларовый'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'комплект'}], 'text': 'комплект'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'включать'}], 'text': 'включены'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}, {'lex': 'все'}], 'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дополнительный'}], 'text': 'дополнительные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'функция'}], 'text': 'функции'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '3'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'стандарт'}], 'text': 'Стандарт'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}, {'lex': 'нея'}], 'text': 'неё'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'входить'}], 'text': 'входит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '25'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'text': '20'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вполне'}], 'text': 'Вполне'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подходить'}], 'text': 'подходит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'новый'}, {'lex': 'новое'}], 'text': 'нового'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'стартапа', 'qual': 'bastard'},
#     {'lex': 'стартап', 'qual': 'bastard'}],
#    'text': 'стартапа'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}, {'lex': 'стоить'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}, {'lex': 'долларовый'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'именно'}], 'text': 'именно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'она'}, {'lex': 'ее'}], 'text': 'её'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'купить'}], 'text': 'купил'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервиса'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'написание'}], 'text': 'написания'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обзор'}], 'text': 'обзора'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '4'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'плюс'}], 'text': 'Плюс'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'отличаться'}], 'text': 'Отличается'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предыдущий'}], 'text': 'предыдущей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможностью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживание'}], 'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '100'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ', '},
#   {'text': '50'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'очень'}], 'text': 'Очень'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'тариф'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'крупный'}], 'text': 'крупных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервисов'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}, {'lex': 'стоить'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'text': '49'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}, {'lex': 'долларовый'}], 'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'довольно'}, {'lex': 'довольный'}],
#    'text': 'Довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}, {'lex': 'больший'}], 'text': 'большие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'за'}], 'text': 'за'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'они'}], 'text': 'они'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обычно'}, {'lex': 'обычный'}], 'text': 'обычно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лихва'}], 'text': 'лихвой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'окупаться'}], 'text': 'окупаются'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '5'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'версия'}], 'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'lex': 'про'}], 'text': 'Про'},
#   {'text': '»'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'стоять'}, {'lex': 'стоить'}], 'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'почти'}, {'lex': 'почесть'}, {'lex': 'почтить'}],
#    'text': 'почти'},
#   {'text': ' '},
#   {'text': '100'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'доллар'}, {'lex': 'долларовый'}], 'text': 'долларов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'иметь'}], 'text': 'имеет'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'возможность'}], 'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отслеживать'}], 'text': 'отследить'},
#   {'text': ' '},
#   {'text': '250'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещение'}], 'text': 'посещений'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сто'}], 'text': 'ста'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страницах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'Тариф'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подходить'}], 'text': 'подходит'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'монстр'}], 'text': 'монстров'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}], 'text': 'большой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посещаемость'}], 'text': 'посещаемостью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'большой'}, {'lex': 'больший'}, {'lex': 'большее'}],
#    'text': 'большим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'количество'}], 'text': 'количеством'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'быть'}, {'lex': 'есть'}], 'text': 'Есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналоги'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'я'}], 'text': 'Я'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полениться'}], 'text': 'поленился'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'собирать'}], 'text': 'собрал'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'еще'}], 'text': 'еще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пара'}, {'lex': 'пар'}], 'text': 'пару'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'ссылка'}], 'text': 'ссылок'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналогами'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предлагать'}], 'text': 'предлагают'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'такой'}], 'text': 'такие'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'же'}], 'text': 'же'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'услуга'}], 'text': 'услуги'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'немного'}, {'lex': 'немногий'}], 'text': 'немного'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'дешево'}, {'lex': 'дешевый'}], 'text': 'дешевле'},
#   {'text': '. '},
#   {'text': '1'},
#   {'text': '. '},
#   {'analysis': [], 'text': 'Google'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'Analytics'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'бесплатный'}], 'text': 'бесплатный'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сбор'}], 'text': 'сбора'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'анализ'}], 'text': 'анализа'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статистика'}, {'lex': 'статистик'}],
#    'text': 'статистики'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'вывод'}], 'text': 'вывод'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статистика'}, {'lex': 'статистик'}],
#    'text': 'статистики'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'наглядный'}], 'text': 'наглядной'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'форма'}], 'text': 'форме'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'без'}], 'text': 'без'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'разнообразный'}], 'text': 'разнообразных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'рейтинг'}, {'lex': 'рейтинговый'}],
#    'text': 'рейтингов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'счетчик'}], 'text': 'счетчиков'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'очень'}], 'text': 'Очень'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'подробный'}], 'text': 'подробная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вещь'}], 'text': 'вещь'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'рекомендовать'}], 'text': 'Рекомендую'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'к'}], 'text': 'к'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сам'}], 'text': 'сам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'пользоваться'}], 'text': 'пользуюсь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}, {'lex': 'оно'}, {'lex': 'они'}, {'lex': 'има'}],
#    'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'блог'}], 'text': 'блога'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'text': '2'},
#   {'text': '. '},
#   {'analysis': [], 'text': 'MapSurface'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'сам'}], 'text': 'сам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'еще'}], 'text': 'еще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'использовать'}], 'text': 'использовал'},
#   {'text': ' ('},
#   {'analysis': [{'lex': 'т'}], 'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'lex': 'к'}], 'text': 'к'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'предпочитать'}], 'text': 'предпочел'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': '), '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'врядли', 'qual': 'bastard'},
#     {'lex': 'врядль', 'qual': 'bastard'},
#     {'lex': 'врядлить', 'qual': 'bastard'},
#     {'lex': 'врядлять', 'qual': 'bastard'}],
#    'text': 'врядли'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'быть'}], 'text': 'будучи'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'плохой'}], 'text': 'плохим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'собирать'}], 'text': 'собрал'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бы'}], 'text': 'бы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'множество'}], 'text': 'множество'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'положительный'}], 'text': 'положительных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отзыв'}], 'text': 'отзывов'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'к'}], 'text': 'К'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сожаление'}], 'text': 'сожалению'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'он'}], 'text': 'он'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сейчас'}], 'text': 'сейчас'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'находиться'}], 'text': 'находится'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'статус'}], 'text': 'статусе'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'закрытый'}, {'lex': 'закрывать'}],
#    'text': 'закрытой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бета'}], 'text': 'беты'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вывод'}], 'text': 'Вывод'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'использовать'}], 'text': 'Использовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'можно'}], 'text': 'можно'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}, {'lex': 'нужный'}], 'text': 'нужно'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'вот'}], 'text': 'Вот'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тариф'}], 'text': 'тарифы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'довольно'}, {'lex': 'довольный'}],
#    'text': 'довольно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'больно'}, {'lex': 'больной'}], 'text': 'больно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'кусаться'}], 'text': 'кусаются'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обычно'}, {'lex': 'обычный'}], 'text': 'обычно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'этот'}], 'text': 'эти'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'потом'}, {'lex': 'пот'}], 'text': 'потом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'лихва'}], 'text': 'лихвой'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отбиваться'}], 'text': 'отбиваются'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'повышение'}], 'text': 'повышении'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конвертация'}], 'text': 'конвертации'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'посетитель'}], 'text': 'посетителей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньги'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'использовать'}], 'text': 'Использовать'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сервис'}], 'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'нужно'}, {'lex': 'нужный'}], 'text': 'нужно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'тестирование'}], 'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'рекламный'}], 'text': 'рекламных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'место'}], 'text': 'мест'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'удобство'}], 'text': 'удобства'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'отдельный'}], 'text': 'отдельных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'страница'}], 'text': 'страниц'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}], 'text': 'что'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'помогать'}], 'text': 'помогает'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'опять'}], 'text': 'опять'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'же'}], 'text': 'же'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'повышать'}], 'text': 'повысить'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'конвертация'}], 'text': 'конвертацию'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'общий'}], 'text': 'общем'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'целое'}, {'lex': 'целый'}], 'text': 'целом'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезная'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вещь'}], 'text': 'вещь'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'каждый'}], 'text': 'каждого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'владелец'}], 'text': 'владельца'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сайт'}], 'text': 'сайтов'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилиста'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вообще'}], 'text': 'вообще'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'практически'}, {'lex': 'практический'}],
#    'text': 'практически'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'обязательный'}], 'text': 'обязательна'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'к'}], 'text': 'К'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'счастие'}], 'text': 'счастью'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'человек'}], 'text': 'людей'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'который'}], 'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'поиздержаться'}], 'text': 'поиздержались'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'деньги'}, {'lex': 'деньга'}], 'text': 'деньгами'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'это'}, {'lex': 'этот'}], 'text': 'этом'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'месяц'}], 'text': 'месяце'},
#   {'text': ' — '},
#   {'analysis': [{'lex': 'быть'}, {'lex': 'есть'}], 'text': 'есть'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'полезный'}], 'text': 'полезные'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'аналог'}], 'text': 'аналоги'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'автор'}], 'text': 'Автор'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'ярослав'}, {'lex': 'ярослава'}], 'text': 'Ярослав'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'бирзула', 'qual': 'bastard'},
#     {'lex': 'бирзувать', 'qual': 'bastard'}],
#    'text': 'Бирзул'},
#   {'text': ' ('},
#   {'analysis': [], 'text': 'DezmASter'},
#   {'text': ')'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [{'lex': 'источник'}], 'text': 'Источник'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'блог'}], 'text': 'Блог'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'юзабилити', 'qual': 'bastard'},
#     {'lex': 'юзабилить', 'qual': 'bastard'},
#     {'lex': 'юзабилитя', 'qual': 'bastard'}],
#    'text': 'юзабилити'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'веб'}], 'text': 'веб'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'интерфейс'}], 'text': 'интерфейсов'},
#   {'text': '.'},
#   {'text': '\r\n'}],
#  [{'analysis': [], 'text': 'PS'},
#   {'text': ': '},
#   {'analysis': [{'lex': 'весь'}, {'lex': 'все'}], 'text': 'Всех'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'прошедшее'},
#     {'lex': 'прошедший'},
#     {'lex': 'пройти'},
#     {'lex': 'проходить'}],
#    'text': 'прошедшим'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'новый'}, {'lex': 'новое'}], 'text': 'Новым'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'год'}], 'text': 'годом'},
#   {'text': '! '},
#   {'analysis': [{'lex': 'от'}], 'text': 'От'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'весь'}, {'lex': 'всевать'}], 'text': 'всей'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'душа'}, {'lex': 'душ'}, {'lex': 'душить'}],
#    'text': 'души'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'желать'}], 'text': 'желаю'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'все'}, {'lex': 'всего'}, {'lex': 'весь'}],
#    'text': 'всего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'самый'}, {'lex': 'сам'}], 'text': 'самого'},
#   {'text': '-'},
#   {'analysis': [{'lex': 'самый'}, {'lex': 'сам'}], 'text': 'самого'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'хороший'}], 'text': 'лучшего'},
#   {'text': ', '},
#   {'analysis': [{'lex': 'что'}, {'lex': 'чего'}], 'text': 'чего'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вы'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'желать'}], 'text': 'желаете'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'самый'}], 'text': 'самых'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'сокровенный'}], 'text': 'сокровенных'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'мечта'}], 'text': 'мечтах'},
#   {'text': '. '},
#   {'analysis': [{'lex': 'удачно'}, {'lex': 'удачный'}], 'text': 'Удачно'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'проводить'}], 'text': 'провести'},
#   {'text': ' '},
#   {'analysis': [{'lex': 'время'}], 'text': 'время'},
#   {'text': '.'},
#   {'text': '\r\n'}]]

# %%
ambig_lem = []
for p in ambig:
    for w in p:
        if "analysis" in w:
            if w["analysis"]:
                ambig_lem.append(w["analysis"][0]["lex"])
ambig_lem[:10]
# Out:
# ['сегодняшний',
#  'заметка',
#  'будет',
#  'о',
#  'сервис',
#  'отслеживание',
#  'активность',
#  'пользователь',
#  'я',
#  'не']

# %%
count = 0
for n in range(len(ambig_lem) - 1):
    if ambig_lem[n] != disambig_lem[n]:
        count+=1
        print(stem_tokens[n], ambig_lem[n], disambig_lem[n])
print('Различий: ', count)
# Out:
# будет будет быть
# говорящим говорить говорящий
# выше высоко выше
# тому то тот
# тем то тем
# теплее теплый тепло
# тем то тем
# больше больше много
# тем то тем
# Разумеется разуметься разумеется
# им он они
# может мочь может
# есть быть есть
# этого это этот
# больше больше много
# будет будет быть
# будет будет быть
# стартапа стартапа стартап
# Стоит стоять стоить
# этого это этот
# этого это этот
# нужно нужно нужный
# этом это этот
# прошедшим прошедшее прошедший
# всего все весь
# Различий:  25

# %% [markdown]
# * С местоимениеем *им* происходит то же самое, что и при сравнении пайморфи и майстема. На удивление, правильным является вариант разбора без дизамбигуации – "...пользоваться *им* может каждый...".
# * По-разному разбирается слово *разумеется*: без дизамбигуации оно разбирается как глагол, с дизамбигуацией – как вводное слово (утвердительная частица).
# * Глагол *стоит* так же разбирается по-разному: стоять (без) и стоить (с – и это правильный вариант).
# * В целом, нельзя однозначно сказать, какой вариант лучше, как и в случае с пайморфи и майстемом, хотя на большом объеме, скорее всего, лучше использовать дизамбигуацию, т.к. в таком случае исключаются разборы типа *будет – будет*.
